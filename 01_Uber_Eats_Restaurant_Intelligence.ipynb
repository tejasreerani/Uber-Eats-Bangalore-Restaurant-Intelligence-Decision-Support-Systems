# %% [markdown]
# <a href="https://colab.research.google.com/github/tejasreerani/Uber-Eats-Bangalore-Restaurant-Intelligence-Decision-Support-Systems/blob/main/01_Uber_Eats_Restaurant_Intelligence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
# Read CSV file
df=pd.read_csv('Uber_Eats_data.csv')
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 23188                                 Izakaya Gastro Pub          Yes
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 23190                             Keys Cafe - Keys Hotel           No
# 23191                                            Bhagini           No
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table    rate  votes                             phone  \
# 0            Yes   4.1/5    775    080 42297555\r\n+91 9743772233
# 1             No   4.1/5    787                      080 41714161
# 2             No   3.8/5    918                    +91 9663487993
# 3             No   3.7/5     88                    +91 9620009302
# 4             No   3.8/5    166  +91 8026612447\r\n+91 9901210005
# ...          ...     ...    ...                               ...
# 23188        Yes  3.8 /5    128    +91 7625087121\n+91 8050587483
# 23189         No  3.9 /5     77                      080 49435000
# 23190         No  2.8 /5    161      080 39451000\n+91 8884038484
# 23191         No  2.5 /5     81                      080 65951222
# 23192        Yes  4.3 /5    236                      080 49652769
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# ...                           ...                  ...
# 23188                  Whitefield   Bar, Casual Dining
# 23189                  Whitefield     Fine Dining, Bar
# 23190                  Whitefield   Casual Dining, Bar
# 23191                  Whitefield   Casual Dining, Bar
# 23192  ITPL Main Road, Whitefield                  Bar
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 23188  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 23189                                   Rooftop Ambience
# 23190  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 23191                               Biryani, Andhra Meal
# 23192                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 23188     North Indian, Continental, Mediterranean
# 23189                                  Finger Food
# 23190           Chinese, Continental, North Indian
# 23191  Andhra, South Indian, Chinese, North Indian
# 23192                                  Finger Food
#
#       approx_cost(for two people) listed_in(type) listed_in(city)
# 0                             800          Buffet    Banashankari
# 1                             800          Buffet    Banashankari
# 2                             800          Buffet    Banashankari
# 3                             300          Buffet    Banashankari
# 4                             600          Buffet    Banashankari
# ...                           ...             ...             ...
# 23188                       1,200   Pubs and bars      Whitefield
# 23189                       2,000   Pubs and bars      Whitefield
# 23190                       1,200   Pubs and bars      Whitefield
# 23191                         800   Pubs and bars      Whitefield
# 23192                       2,500   Pubs and bars      Whitefield
#
# [23193 rows x 13 columns]

# %%
# Connect to sqlite3 database
conn=sqlite3.connect('Uber_Eats.db')
mycursor=conn.cursor()

# %%
# Remove duplicates & data cleaning

df=df.drop_duplicates()

# %%
# Cleaning the data

def clean_rate(x):
    if isinstance(x, str) and "/" in x:
        return float(x.split("/")[0])
    else:
        return None

df.loc[:, "rate"] = df["rate"].apply(clean_rate)

# %%
df.columns = ['name', 'online_order', 'book_table', 'rate', 'votes', 'phone', 'location', 'rest_type', 'dish_liked', 'cuisines', 'approx_cost', 'listed_type', 'listed_city']
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes', 'phone',
#        'location', 'rest_type', 'dish_liked', 'cuisines', 'approx_cost',
#        'listed_type', 'listed_city'],
#       dtype='object')

# %%
data=df.values.tolist()
data
# Out:
# [['Jalsa',
#   'Yes',
#   'Yes',
#   4.1,
#   775,
#   '080 42297555\r\n+91 9743772233',
#   'Banashankari',
#   'Casual Dining',
#   'Pasta, Lunch Buffet, Masala Papad, Paneer Lajawab, Tomato Shorba, Dum Biryani, Sweet Corn Soup',
#   'North Indian, Mughlai, Chinese',
#   '800',
#   'Buffet',
#   'Banashankari'],
#  ['Spice Elephant',
#   'Yes',
#   'No',
#   4.1,
#   787,
#   '080 41714161',
#   'Banashankari',
#   'Casual Dining',
#   'Momos, Lunch Buffet, Chocolate Nirvana, Thai Green Curry, Paneer Tikka, Dum Biryani, Chicken Biryani',
#   'Chinese, North Indian, Thai',
#   '800',
#   'Buffet',
#   'Banashankari'],
#  ['San Churro Cafe',
#   'Yes',
#   'No',
#   3.8,
#   918,
#   '+91 9663487993',
#   'Banashankari',
#   'Cafe, Casual Dining',
#   'Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza',
#   'Cafe, Mexican, Italian',
#   '800',
#   'Buffet',
#   'Banashankari'],
#  ['Addhuri Udupi Bhojana',
#   'No',
#   'No',
#   3.7,
#   88,
#   '+91 9620009302',
#   'Banashankari',
#   'Quick Bites',
#   'Masala Dosa',
#   'South Indian, North Indian',
#   '300',
#   'Buffet',
#   'Banashankari'],
#  ['Grand Village',
#   'No',
#   'No',
#   3.8,
#   166,
#   '+91 8026612447\r\n+91 9901210005',
#   'Basavanagudi',
#   'Casual Dining',
#   'Panipuri, Gol Gappe',
#   'North Indian, Rajasthani',
#   '600',
#   'Buffet',
#   'Banashankari'],
#  ['Timepass Dinner',
#   'Yes',
#   'No',
#   3.8,
#   286,
#   '+91 9980040002\r\n+91 9980063005',
#   'Basavanagudi',
#   'Casual Dining',
#   'Onion Rings, Pasta, Kadhai Paneer, Salads, Salad, Roti, Jeera Rice',
#   'North Indian',
#   '600',
#   'Buffet',
#   'Banashankari'],
#  ['Onesta',
#   'Yes',
#   'Yes',
#   4.6,
#   2556,
#   '080 48653961\r\n080 48655715',
#   'Banashankari',
#   'Casual Dining, Cafe',
#   'Farmhouse Pizza, Chocolate Banana, Virgin Mojito, Pasta, Paneer Tikka, Lime Soda, Prawn Pizza',
#   'Pizza, Cafe, Italian',
#   '600',
#   'Cafes',
#   'Banashankari'],
#  ['Penthouse Cafe',
#   'Yes',
#   'No',
#   4.0,
#   324,
#   '+91 8884135549\r\n+91 9449449316',
#   'Banashankari',
#   'Cafe',
#   'Pizza, Mocktails, Coffee, Nachos, Salad, Pasta, Sandwiches',
#   'Cafe, Italian, Continental',
#   '700',
#   'Cafes',
#   'Banashankari'],
#  ['Smacznego',
#   'Yes',
#   'No',
#   4.2,
#   504,
#   '+91 9945230807\r\n+91 9743804471',
#   'Banashankari',
#   'Cafe',
#   'Waffles, Pasta, Coleslaw Sandwich, Choco Waffle, Tacos, Momos, Cheese Nachos',
#   'Cafe, Mexican, Italian, Momos, Beverages',
#   '550',
#   'Cafes',
#   'Banashankari'],
#  ['CafÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â© Down The Alley',
#   'Yes',
#   'No',
#   4.1,
#   402,
#   '080 26724489\r\n+91 7406048982',
#   'Banashankari',
#   'Cafe',
#   'Waffles, Pasta, Crispy Chicken, Honey Chilli Chicken, Sandwich, Coffee, Crepe',
#   'Cafe',
#   '500',
#   'Cafes',
#   'Banashankari'],
#  ['Cafe Shuffle',
#   'Yes',
#   'Yes',
#   4.2,
#   150,
#   '+91 9742166777',
#   'Banashankari',
#   'Cafe',
#   'Mocktails, Peri Fries, Lasagne, Pizza, Chicken Bbq Wings, Virgin Mojito, Nachos',
#   'Cafe, Italian, Continental',
#   '600',
#   'Cafes',
#   'Banashankari'],
#  ['The Coffee Shack',
#   'Yes',
#   'Yes',
#   4.2,
#   164,
#   '+91 9731644212',
#   'Banashankari',
#   'Cafe',
#   'Coffee, Spaghetti, Pancakes, Nachos, Pasta, Sandwich, Garlic Bread',
#   'Cafe, Chinese, Continental, Italian',
#   '500',
#   'Cafes',
#   'Banashankari'],
#  ['Caf-Eleven',
#   'No',
#   'No',
#   4.0,
#   424,
#   '080 49577715',
#   'Banashankari',
#   'Cafe',
#   'Sandwich, Omelette, Ice Tea, Virgin Mojito, Hot Chocolate, Pasta Arrabiata, Hazelnut Cappuccino',
#   'Cafe, Continental',
#   '450',
#   'Cafes',
#   'Banashankari'],
#  ['San Churro Cafe',
#   'Yes',
#   'No',
#   3.8,
#   918,
#   '+91 9663487993',
#   'Banashankari',
#   'Cafe, Casual Dining',
#   'Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza',
#   'Cafe, Mexican, Italian',
#   '800',
#   'Cafes',
#   'Banashankari'],
#  ['Cafe Vivacity',
#   'Yes',
#   'No',
#   3.8,
#   90,
#   '080 26768182\r\n+91 9845704455',
#   'Banashankari',
#   'Cafe',
#   'Garlic Bread, Burgers, Sandwiches, Pizza, Hot Chocolate Fudge, Waffles, Potato Wedges',
#   'Cafe',
#   '650',
#   'Cafes',
#   'Banashankari'],
#  ['Catch-up-ino',
#   'Yes',
#   'No',
#   3.9,
#   133,
#   '+91 9972988038\r\n+91 9900121238',
#   'Banashankari',
#   'Cafe',
#   'Momos, Mushroom Bruschettas, Jalapeno Cheeseballs, Pasta, Red Velvet Shake, Red Velvet Milkshake, Maggi',
#   'Cafe, Fast Food, Continental, Chinese, Momos',
#   '800',
#   'Cafes',
#   'Banashankari'],
#  ["Kirthi's Biryani",
#   'Yes',
#   'No',
#   3.8,
#   144,
#   '080 26711554\r\n+91 9741406338',
#   'Banashankari',
#   'Cafe',
#   'Pasta, Gelato, Garlic Bread, Mojito, Nachos, Paneer Pizza, Mocktails',
#   'Chinese, Cafe, Italian',
#   '700',
#   'Cafes',
#   'Banashankari'],
#  ['T3H Cafe',
#   'No',
#   'No',
#   3.9,
#   93,
#   '+91 8884726600',
#   'Banashankari',
#   'Cafe',
#   'Cheese Maggi, Peri Peri Fries, Pasta Arrabiata',
#   'Cafe, Italian, American',
#   '300',
#   'Cafes',
#   'Banashankari'],
#  ['The Vintage Cafe',
#   'Yes',
#   'No',
#   3.0,
#   62,
#   '+91 9880016665\r\n+91 8217311687',
#   'Banashankari',
#   'Cafe',
#   'Burgers, Caramel Milkshake, Iced Coffee, Iced Tea',
#   'Cafe, French, North Indian',
#   '400',
#   'Cafes',
#   'Banashankari'],
#  ['Woodee Pizza',
#   'Yes',
#   'No',
#   3.7,
#   180,
#   '+91 7406822844',
#   'Banashankari',
#   'Cafe',
#   'Pizza, Garlic Bread',
#   'Cafe, Pizza, Fast Food, Beverages',
#   '500',
#   'Cafes',
#   'Banashankari'],
#  ['My Tea House',
#   'Yes',
#   'No',
#   3.6,
#   62,
#   '080 65975430\r\n+91 7337733798',
#   'Banashankari',
#   'Quick Bites, Cafe',
#   'Pasta, Iced Tea',
#   'Italian, Fast Food, Cafe, European',
#   '600',
#   'Cafes',
#   'Banashankari'],
#  ["Srinathji's Cafe",
#   'No',
#   'No',
#   3.8,
#   148,
#   '080 26600704\r\n+91 9342593424',
#   'Basavanagudi',
#   'Casual Dining, Cafe',
#   'Paratha, Sandwich, Chilli Idli, Noodles, Sandwiches, Lime Soda',
#   'North Indian, Cafe, Chinese, Fast Food',
#   '550',
#   'Cafes',
#   'Banashankari'],
#  ['Redberrys',
#   'Yes',
#   'No',
#   4.0,
#   219,
#   '+91 9148421256',
#   'Basavanagudi',
#   'Cafe',
#   'Pizza, Fries, Anjeer Ice Cream, Sandwiches, Gelato, Burgers, Kesar Badam',
#   'Cafe, Italian',
#   '600',
#   'Cafes',
#   'Banashankari'],
#  ['Foodiction',
#   'Yes',
#   'No',
#   2.8,
#   506,
#   '+91 9916107070',
#   'Banashankari',
#   'Quick Bites',
#   'Burgers, Lassi, Chicken Grill, Naan, Momos, Chicken Burger, Biryani',
#   'North Indian, Fast Food, Chinese, Burger',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Ovenstory Pizza',
#   'Yes',
#   'No',
#   3.9,
#   172,
#   '+91 7738383000',
#   'Banashankari',
#   'Delivery',
#   'Paneer Tikka, Garlic Bread, Thin Crust Pizza, Falafel, Veggie Pizza',
#   'Pizza',
#   '750',
#   'Delivery',
#   'Banashankari'],
#  ['Faasos',
#   'Yes',
#   'No',
#   4.2,
#   415,
#   '+91 7700020020',
#   'Banashankari',
#   'Quick Bites',
#   'Rolls, Veggie Wrap, Chocolate Fantasy, Rice Bowls, Chicken Rice, Paneer Makhanwala, Chicken Tikka Wrap',
#   'North Indian, Biryani, Fast Food',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Behrouz Biryani',
#   'Yes',
#   'No',
#   3.9,
#   230,
#   '+91 7022260661\r\n+91 7022260662',
#   'Banashankari',
#   'Delivery',
#   'Raita, Gulab Jamun, Paneer Biryani, Vegetable Biryani, Gosht Dum Biryani, Chicken Biryani, Murgh Biryani',
#   'Biryani',
#   '650',
#   'Delivery',
#   'Banashankari'],
#  ['Szechuan Dragon',
#   'Yes',
#   'No',
#   4.2,
#   1647,
#   '00 919663567711\r\n+91 9916326323',
#   'Banashankari',
#   'Casual Dining',
#   'Noodles, Momos, Veg Manchow Soup, Kung Pao Chicken, Chicken Lollipop, Chop Suey, Dragon Chicken',
#   'Chinese, Thai, Momos',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['Empire Restaurant',
#   'Yes',
#   'No',
#   4.4,
#   4884,
#   '080 49653266',
#   'Jayanagar',
#   'Casual Dining',
#   'Chicken Tikka Masala, Mutton Keema Dosa, Mutton Biryani, Raan Biryani, Brain Fry, Chicken Grill, Ghee Rice',
#   'North Indian, Mughlai, South Indian, Chinese',
#   '750',
#   'Delivery',
#   'Banashankari'],
#  ['Chaatimes',
#   'Yes',
#   'No',
#   3.8,
#   133,
#   '+91 8884232233',
#   'Basavanagudi',
#   'Quick Bites',
#   'Dabeli, Faluda, Masala Poori, Sandwiches, Tokri Chaat, Pav Bhaji, Dahipuri',
#   'Street Food, Fast Food',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ["McDonald's",
#   'Yes',
#   'No',
#   3.9,
#   286,
#   '080 66000666\r\n080 42005285',
#   'Banashankari',
#   'Quick Bites',
#   'Burgers, Fries, Hot Chocolate',
#   'Burger, Fast Food',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ["Domino's Pizza",
#   'Yes',
#   'No',
#   3.9,
#   540,
#   '080 26710070\r\n18602100000',
#   'Banashankari',
#   'Quick Bites',
#   'Pane Pizza, Lava Cake, Pasta, Stuffed Garlic Bread, Chocolava Cake, Tacos',
#   'Pizza, Fast Food',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['Onesta',
#   'Yes',
#   'Yes',
#   4.6,
#   2556,
#   '080 48653961\r\n080 48655715',
#   'Banashankari',
#   'Casual Dining, Cafe',
#   'Farmhouse Pizza, Chocolate Banana, Virgin Mojito, Pasta, Paneer Tikka, Lime Soda, Prawn Pizza',
#   'Pizza, Cafe, Italian',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['Hotboxit',
#   'No',
#   'No',
#   3.8,
#   36,
#   '+91 7026677677\r\n+91 7026577577',
#   'Banashankari',
#   'Delivery',
#   'Prompt Service',
#   'North Indian, Continental, Italian',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Kitchen Garden',
#   'Yes',
#   'No',
#   3.6,
#   244,
#   '080 49652867',
#   'Kumaraswamy Layout',
#   'Quick Bites',
#   'Biryani',
#   'North Indian, Chinese',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Recipe',
#   'Yes',
#   'No',
#   4.0,
#   804,
#   '+91 8043755256\r\n+91 9886073774',
#   'Kumaraswamy Layout',
#   'Casual Dining',
#   'Butter Chicken, Noodles, Thali, Biryani',
#   'North Indian, Chinese, Biryani, Rolls',
#   '450',
#   'Delivery',
#   'Banashankari'],
#  ['Beijing Bites',
#   'Yes',
#   'No',
#   3.7,
#   679,
#   '080 28606888\r\n080 28606886',
#   'Rajarajeshwari Nagar',
#   'Casual Dining',
#   'Momos, Dragon Chicken, Hakka Noodles, Chowmein, Chop Suey, Chilli Garlic Noodles, Garlic Rice',
#   'Chinese, Thai',
#   '850',
#   'Delivery',
#   'Banashankari'],
#  ['Tasty Bytes',
#   'Yes',
#   'No',
#   3.1,
#   245,
#   '+91 8553317408\r\n+91 7899687127',
#   'Kumaraswamy Layout',
#   'Quick Bites',
#   'Paratha, Pasta',
#   'North Indian, Chinese, Momos, Rolls',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Corner House Ice Cream',
#   'No',
#   'No',
#   4.3,
#   345,
#   '080 26713965\r\n+91 9845444155',
#   'Banashankari',
#   'Dessert Parlor',
#   'Hot Chocolate Fudge, Vanilla Ice Cream, Fudge Cake, Chocolate Mousse',
#   'Ice Cream, Desserts',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Biryanis And More',
#   'Yes',
#   'No',
#   4.0,
#   618,
#   '080 48542442\r\n+91 7337271771',
#   'Jayanagar',
#   'Casual Dining',
#   'Prawn Biryani, Dragon Chicken, Chicken Boneless Biryani, Afghani Biryani, Mughlai Biryani, Paneer Tikka Biryani, Gongura Biryani',
#   'Biryani, North Indian, Chinese, Andhra, South Indian',
#   '750',
#   'Delivery',
#   'Banashankari'],
#  ['Roving Feast',
#   'No',
#   'No',
#   4.0,
#   1047,
#   '080 42024092\r\n080 42274242',
#   'Banashankari',
#   'Quick Bites',
#   'Pasta, Momos, Rolls, Chicken Roll, Chilli Chicken, Paneer Roll, Spaghetti',
#   'Italian, Continental, Fast Food, Chinese, Momos',
#   '450',
#   'Delivery',
#   'Banashankari'],
#  ['FreshMenu',
#   'Yes',
#   'No',
#   3.9,
#   627,
#   '080 40424242',
#   'Banashankari',
#   'Delivery',
#   'Salads, Sandwiches, Salad, Thai Rice, Pasta, Noodles, Pizza',
#   'Healthy Food, Chinese, Biryani, North Indian, Continental, Salad, American, Burger',
#   '450',
#   'Delivery',
#   'Banashankari'],
#  ['Wamama',
#   'Yes',
#   'Yes',
#   4.2,
#   354,
#   '+91 8042111599\r\n+91 8971818009',
#   'Banashankari',
#   'Casual Dining',
#   'Sushi, Noodles, Wine, Khau Suey, Mocktails, Yakisoba, Spring Roll',
#   'Asian, Korean, Indonesian, Japanese, Chinese, Thai, Momos',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['Peppy Peppers',
#   'No',
#   'No',
#   4.2,
#   244,
#   '+91 8042297555\r\n+91 7022455300',
#   'Banashankari',
#   'Casual Dining',
#   'Pasta, Pepper Pizza, Paneer Pizza, Peppy Paneer, Nachos, Supreme Pizza, Manchow Soup',
#   'Italian, North Indian, Mexican',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['Goa 0 Km',
#   'Yes',
#   'Yes',
#   3.6,
#   163,
#   '080 49653548',
#   'Kumaraswamy Layout',
#   'Casual Dining',
#   'Sea Food, Crab Meat, Crab Soup, Fish Curry, Chicken Cafreal, Butter Naan, Butter Chicken',
#   'Goan, Seafood, North Indian, Chinese, Biryani',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['1947',
#   'No',
#   'Yes',
#   4.0,
#   808,
#   '080 26791213\r\n+91 9739989446',
#   'Banashankari',
#   'Casual Dining',
#   'Salads, Panneer Butter Masala, Rabri, Gajar Ka Halwa, Manchow Soup, Aam Panna, Tomato Basil Soup',
#   'North Indian, Chinese',
#   '850',
#   'Delivery',
#   'Banashankari'],
#  ['Kabab Magic',
#   'Yes',
#   'No',
#   4.1,
#   1720,
#   '080 26570381',
#   'Basavanagudi',
#   'Quick Bites',
#   'Grape Juice, Chicken Grill, Chicken Tikka Roll, Shawarma Roll, Chicken Shawarama, Biryani Combo, Rolls',
#   'North Indian, Kebab, Chinese, Fast Food',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Gustoes Beer House',
#   'No',
#   'No',
#   4.1,
#   868,
#   '080 49653521',
#   'Banashankari',
#   'Pub',
#   'Beer, Wedges, Pizza, Nachos, Salads, Papaya Salad, Buffalo Wings',
#   'Continental, Italian, Mexican, North Indian, Chinese, Steak',
#   '1,200',
#   'Delivery',
#   'Banashankari'],
#  ['The Biryani Cafe',
#   'No',
#   'No',
#   4.1,
#   520,
#   '+91 7010846043',
#   'Banashankari',
#   'Quick Bites',
#   'Vegetable Biryani, Ginger Chicken, Chicken Biryani, Donne Biryani, Chicken Kebab, Egg Bhurji, Dum Biryani',
#   'Biryani, Chinese, Kebab',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Rolls On Wheels',
#   'No',
#   'No',
#   3.6,
#   299,
#   '+91 9071734101\r\n+91 9071496800',
#   'Banashankari',
#   'Quick Bites',
#   'Rolls, Momos, Fries, Veggie Roll, Chicken Kebab Roll, Paneer Roll, Cheese Roll',
#   'Fast Food, Rolls, Momos',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Sri Guru Kottureshwara Davangere Benne Dosa',
#   'Yes',
#   'No',
#   4.1,
#   558,
#   '+91 9448305384\r\n+91 9060079480',
#   'Basavanagudi',
#   'Quick Bites',
#   'Benne Dosa, Mirchi Bajji, Filter Coffee, Poha, Tea, Butter Dosa, Crispy Dosa',
#   'South Indian',
#   '150',
#   'Delivery',
#   'Banashankari'],
#  ['Upahar Sagar',
#   'No',
#   'No',
#   3.8,
#   39,
#   '+91 9164571705\r\n080 26760336',
#   'Banashankari',
#   'Quick Bites',
#   'Masala Dosa',
#   'South Indian, Chinese, North Indian',
#   '350',
#   'Delivery',
#   'Banashankari'],
#  ['Frozen Bottle',
#   'Yes',
#   'No',
#   4.2,
#   146,
#   '080 48664811',
#   'Banashankari',
#   'Beverage Shop',
#   'Berryblast, Waffles, Cheesecake, Salted Caramel',
#   'Beverages, Desserts, Ice Cream',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Meghana Foods',
#   'Yes',
#   'No',
#   4.4,
#   4401,
#   '080 49653564',
#   'Jayanagar',
#   'Casual Dining',
#   'Chicken Boneless Biryani, Hyderabadi Biryani, Paneer Biryani, Tandoori Chicken, Vegetable Biryani, Chicken Kebab, Raita',
#   'Biryani, North Indian, Chinese',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['Nandhini Deluxe',
#   'No',
#   'No',
#   2.6,
#   283,
#   '080 26890011\r\n080 26890033',
#   'Banashankari',
#   'Casual Dining',
#   'Biryani, Chicken Guntur, Thali, Buttermilk, Manchurian',
#   'North Indian',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ["Vi Ra's Bar and Restaurant",
#   'No',
#   'No',
#   3.3,
#   62,
#   '+91 9845063930\r\n+91 7411148111',
#   'Banashankari',
#   'Bar',
#   'Chilli Chicken',
#   'South Indian, North Indian, Chinese',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['Chatar Patar',
#   'No',
#   'No',
#   3.7,
#   65,
#   '+91 7619353103',
#   'Banashankari',
#   'Quick Bites',
#   'Panipuri, Chaat, Noodles, Dahi Bhalle',
#   'Fast Food, Street Food',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Polar Bear',
#   'Yes',
#   'No',
#   3.8,
#   71,
#   '080 49652725',
#   'Basavanagudi',
#   'Dessert Parlor',
#   'Hot Chocolate Fudge',
#   'Ice Cream, Desserts, Beverages, Sandwich',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ["Kidambi's Kitchen",
#   'No',
#   'No',
#   3.5,
#   52,
#   '080 42112211\r\n+91 9880412211',
#   'Banashankari',
#   'Quick Bites',
#   'Rooftop Ambience',
#   'South Indian',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Mane Thindi',
#   'No',
#   'No',
#   3.7,
#   130,
#   '+91 9964410276',
#   'Banashankari',
#   'Quick Bites',
#   'Coffee, Tea, Kesari Bath, Open Dosa, Vada, Idli, Bread Dosa',
#   'South Indian',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ['Floured-Baked With Love',
#   'No',
#   'No',
#   3.8,
#   45,
#   '+91 9845552266\n+91 9845552288',
#   'Banashankari',
#   'Takeaway, Delivery',
#   'Cup Cake, Chocolate Cake',
#   'Bakery',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Bengaluru Coffee House',
#   'Yes',
#   'No',
#   4.1,
#   201,
#   '+91 9740180090',
#   'Banashankari',
#   'Quick Bites',
#   'Masala Dosa, Tirupathi Pongal, Filter Coffee, Vada, Kharabath, Kali Dosa, Rava Idli',
#   'South Indian, North Indian, Chinese, Street Food',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Anna Kuteera',
#   'Yes',
#   'No',
#   4.0,
#   771,
#   '+91 9620009302',
#   'Banashankari',
#   'Casual Dining',
#   'Panner Tikka, Kulfi, Coffee, Pav Bhaji, Carrot Halwa, Fried Rice, Set Dosa',
#   'South Indian, North Indian, Chinese',
#   '450',
#   'Delivery',
#   'Banashankari'],
#  ['Darbar',
#   'No',
#   'No',
#   3.0,
#   98,
#   '+91 8861271465',
#   'Banashankari',
#   'Bar',
#   'Paneer Tikka, Dal Kichadi, French Fries',
#   'North Indian, Chinese',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['Sri Udupi Food Hub',
#   'Yes',
#   'Yes',
#   4.1,
#   175,
#   '+91 9916866033',
#   'Jayanagar',
#   'Casual Dining',
#   'Filter Coffee, Masala Dosa, Idli, Vada',
#   'South Indian, North Indian, Chinese, Beverages',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['House Of Kebabs',
#   'Yes',
#   'No',
#   3.8,
#   540,
#   '080 49653042',
#   'Basavanagudi',
#   'Casual Dining',
#   'Rolls, Shawarma, Butter Chicken, Mutton Biryani, Lahori Chicken, Chicken Roll, Grape Juice',
#   'North Indian, Kebab, Biryani, Chinese',
#   '650',
#   'Delivery',
#   'Banashankari'],
#  ['Roll N Rock',
#   'Yes',
#   'No',
#   3.8,
#   124,
#   '+91 9590941992',
#   'Kumaraswamy Layout',
#   'Quick Bites',
#   'Rolls, Paratha, Chicken Biryani',
#   'Chinese, North Indian, Mughlai, Rolls',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['BOX8- Desi Meals',
#   'Yes',
#   'No',
#   4.1,
#   340,
#   '022 33552698',
#   'Banashankari',
#   'Takeaway, Delivery',
#   'Paratha, Mughlai Chicken, Masala Lemonade, Butter Chicken, Rajma, Sandwich, Salad',
#   'North Indian, Mughlai, Fast Food',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['KFC',
#   'Yes',
#   'No',
#   3.8,
#   505,
#   '080 33994444',
#   'Banashankari',
#   'Quick Bites',
#   'Burgers, French Fries',
#   'Burger, Fast Food',
#   '450',
#   'Delivery',
#   'Banashankari'],
#  ['Roll Over',
#   'Yes',
#   'No',
#   4.1,
#   438,
#   '+91 8884942976\r\n+91 8884942900',
#   'Jayanagar',
#   'Dessert Parlor',
#   'Rolls, Ice Cream Roll, Paan Ice Cream, Coffee, Vanilla Ice Cream, Chocolate Icecreams, Mississippi Mudpie',
#   'Desserts, Ice Cream, Beverages, Fast Food, Sandwich',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Imperial Restaurant',
#   'Yes',
#   'No',
#   3.7,
#   264,
#   '+91 7338431313\r\n080 26741313',
#   'Mysore Road',
#   'Casual Dining',
#   'Kadhai Paneer, Ghee Rice, Chicken Grill, Shawarma, Paratha, Biryani, Butter Chicken',
#   'North Indian, Chinese, Biryani, Beverages',
#   '750',
#   'Delivery',
#   'Banashankari'],
#  ['Wahab',
#   'Yes',
#   'No',
#   3.7,
#   97,
#   '+91 9845088001',
#   'Jayanagar',
#   'Quick Bites',
#   'Chicken Biryani, Rolls',
#   'North Indian, Mughlai, Chinese',
#   '350',
#   'Delivery',
#   'Banashankari'],
#  ['Canton',
#   'Yes',
#   'No',
#   3.6,
#   195,
#   '080 41410069\r\n+91 9611320069',
#   'Jayanagar',
#   'Casual Dining',
#   'Roast Pork, Tai Pai Chicken, Beer, Sweet Corn Chicken Soup, Masala Peanuts, Chinese Chop Suey, Chicken Lollipop',
#   'Chinese, Seafood, Biryani',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['The Blue Wagon - Kitchen',
#   'Yes',
#   'No',
#   4.6,
#   228,
#   '+91 8105485007\r\n+91 8095904280',
#   'Jayanagar',
#   'Cafe',
#   'Pizza, Nachos, Garlic Maggi, Burgers, Cheese Maggi, Bruschetta Bites, Sandwich',
#   'Cafe, Beverages',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Patio 805',
#   'Yes',
#   'Yes',
#   4.1,
#   364,
#   '+91 8884999805',
#   'Jayanagar',
#   'Casual Dining',
#   'Noodles, Laksa Soup, Coffee, Veg Fritters, Vegetarian, Babycorn Manchurian, Mango Salad',
#   'Thai, Vietnamese, Asian, Chinese',
#   '1,200',
#   'Delivery',
#   'Banashankari'],
#  ['Lassi Corner',
#   'Yes',
#   'No',
#   3.7,
#   107,
#   '+91 9972348689\r\n+91 7204756477',
#   'Basavanagudi',
#   'Beverage Shop',
#   'Lassi',
#   'Beverages, Ice Cream',
#   '150',
#   'Delivery',
#   'Banashankari'],
#  ['Sagar Deluxe',
#   'Yes',
#   'No',
#   3.2,
#   167,
#   '080 32963232\r\n+91 9620284767',
#   'Kumaraswamy Layout',
#   'Quick Bites',
#   'Coffee, Chaat',
#   'South Indian, North Indian, Chinese, Juices',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Energy Addaa',
#   'Yes',
#   'No',
#   4.2,
#   64,
#   '080 49652857',
#   'Basavanagudi',
#   'Quick Bites',
#   'Pizza, Nachos, Salads, Peri Peri Fries, Brownie, Pasta Alfredo, Spaghetti',
#   'Salad, Healthy Food, Sandwich, Juices, Burger, Desserts, Pizza',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Tandoori Knight',
#   'Yes',
#   'No',
#   3.0,
#   290,
#   '+91 9035297404\r\n+91 9731504721',
#   'Banashankari',
#   'Quick Bites',
#   'Chicken Grill, Biryani, Roti, Chicken Masala',
#   'North Indian, Chinese, Biryani, Kebab',
#   '450',
#   'Delivery',
#   'Banashankari'],
#  ['Dev Sagar - Food Street',
#   'Yes',
#   'No',
#   4.1,
#   233,
#   '+91 9886204745\r\n0161 26624745',
#   'Basavanagudi',
#   'Quick Bites',
#   'Chaat, Pav Bhaji, Dabeli, Vada Pav, Tawa Pulav, Panipuri, Malpua',
#   'Street Food',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ['Mitraa Da Pizza',
#   'Yes',
#   'No',
#   3.8,
#   115,
#   '+91 7977809237\r\n+91 7752956789',
#   'Kumaraswamy Layout',
#   'Quick Bites',
#   'Pizza, Burgers',
#   'Fast Food, Pizza',
#   '250',
#   'Delivery',
#   'Banashankari'],
#  ['Grazers',
#   'Yes',
#   'Yes',
#   3.9,
#   291,
#   '080 26650668',
#   'Jayanagar',
#   'Cafe',
#   'Burgers, Panneer Butter Masala, Pasta, Hot Dog, Fries, Cheesy Pizza, Potato Wedges',
#   'Cafe, Burger, Continental, Italian, Desserts',
#   '650',
#   'Delivery',
#   'Banashankari'],
#  ['Shakes Theory',
#   'Yes',
#   'No',
#   4.5,
#   155,
#   '+91 9886936896\r\n+91 9620000463',
#   'Jayanagar',
#   'Beverage Shop',
#   'Sandwiches, Thick Shakes, Paan Shake, Brownie Bomb, Fries, Spinach Corn Sandwich, Paneer Peri Peri',
#   'Beverages, Sandwich',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['@Italy',
#   'Yes',
#   'No',
#   4.1,
#   305,
#   '+91 7760579999\r\n+91 7026557799',
#   'Kumaraswamy Layout',
#   'Casual Dining',
#   'Pizza, Pasta, Spinach Salsa, Garlic Bread, Lasagne, Bruschettas, Chocolate Bomb',
#   'Italian',
#   '700',
#   'Delivery',
#   'Banashankari'],
#  ['Old Mumbai Ice Cream',
#   'Yes',
#   'No',
#   3.9,
#   38,
#   '080 49652445',
#   'Banashankari',
#   'Dessert Parlor',
#   'Friendly Staff',
#   'Ice Cream',
#   '150',
#   'Delivery',
#   'Banashankari'],
#  ['Donne Biriyani House',
#   'Yes',
#   'No',
#   3.9,
#   441,
#   '+91 8197743537\r\n080 26690642',
#   'Banashankari',
#   'Quick Bites',
#   'Biryani',
#   'South Indian, North Indian, Chinese, Biryani',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ["Kedia's Fun Food",
#   'Yes',
#   'No',
#   4.3,
#   630,
#   '+91 8867769557',
#   'Jayanagar',
#   'Quick Bites',
#   'Paratha, Vada Pav, Chaat, Pav Bhaji, Panipuri, Masala Poori, Dhokla',
#   'North Indian, Street Food, Juices',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ['Just Shawarma',
#   'Yes',
#   'No',
#   3.9,
#   160,
#   '+91 7676764422',
#   'Kumaraswamy Layout',
#   'Quick Bites',
#   'Whole Meat Shawarma, Fries',
#   'Arabian',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Mini Punjabi Dhaba',
#   'Yes',
#   'No',
#   4.2,
#   287,
#   '+91 9845044074\r\n+91 7406012344',
#   'Banashankari',
#   'Quick Bites',
#   'Panneer Butter Masala, Lassi, Paratha, Jeera Rice, Paneer Parantha, Bhindi Fry, Veg Kolhapuri',
#   'North Indian',
#   '350',
#   'Delivery',
#   'Banashankari'],
#  ['CafÃ\x83Â\x83Ã\x82Â\x83Ã\x83Â\x82Ã\x82Â\x83Ã\x83Â\x83Ã\x82Â\x82Ã\x83Â\x82Ã\x82Â© Down The Alley',
#   'Yes',
#   'No',
#   4.1,
#   402,
#   '080 26724489\r\n+91 7406048982',
#   'Banashankari',
#   'Cafe',
#   'Waffles, Pasta, Crispy Chicken, Honey Chilli Chicken, Sandwich, Coffee, Crepe',
#   'Cafe',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Gokul Veg',
#   'Yes',
#   'No',
#   3.8,
#   469,
#   '+91 9980978388\r\n080 26627612',
#   'Basavanagudi',
#   'Casual Dining',
#   'Masala Papad, Paneer Satay, Vegetable Biryani, Panneer Butter Masala, Tomato Soup, Manchow Soup, Roti',
#   'North Indian, Chinese, Beverages',
#   '750',
#   'Delivery',
#   'Banashankari'],
#  ['Olive - Era',
#   'Yes',
#   'No',
#   3.3,
#   511,
#   '080 42017174\r\n080 42021219',
#   'Kumaraswamy Layout',
#   'Casual Dining',
#   'Shawarma, Biryani, Bbq Chicken, Chicken Grill, Raita',
#   'BBQ, Arabian, Rolls, Chinese, North Indian, Juices, Kebab, Desserts',
#   '550',
#   'Delivery',
#   'Banashankari'],
#  ['Gama Gama',
#   'Yes',
#   'No',
#   3.9,
#   264,
#   '+91 9739946098\r\n+91 9538433344',
#   'Banashankari',
#   'Quick Bites',
#   'Jowar Roti, Buttermilk, Sabudana Vada, Thali, Mirchi Bajji, Brinjal Curry',
#   'South Indian',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ['The Vintage Cafe',
#   'Yes',
#   'No',
#   3.0,
#   62,
#   '+91 9880016665\r\n+91 8217311687',
#   'Banashankari',
#   'Cafe',
#   'Burgers, Caramel Milkshake, Iced Coffee, Iced Tea',
#   'Cafe, French, North Indian',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Pizza Hut',
#   'Yes',
#   'No',
#   3.8,
#   693,
#   '080 39883988\r\n080 26710999',
#   'Banashankari',
#   'Casual Dining',
#   'Supreme Pizza, Potato Wedges, Masala Lemonade, Tandoori Paneer, Exotic Garlic Bread',
#   'Pizza, Fast Food',
#   '750',
#   'Delivery',
#   'Banashankari'],
#  ['Mangalore Pearl',
#   'Yes',
#   'No',
#   3.8,
#   242,
#   '+91 8880888315\r\n+91 9019966667',
#   'Jayanagar',
#   'Casual Dining',
#   'Neer Dosa, Sea Food, Ghee Rice, Marwai Sukka, Egg Biryani, Kori Roti, Thai Fish',
#   'Mangalorean, Seafood, Chinese, Biryani',
#   '650',
#   'Delivery',
#   'Banashankari'],
#  ['Twiststick House',
#   'Yes',
#   'No',
#   4.1,
#   163,
#   '+91 9916538249',
#   'Basavanagudi',
#   'Quick Bites',
#   'White Pasta, Noodles, Babycorn Manchurian, Pizza, Veg Momos, Fry Momos, Tawa Pulav',
#   'Continental, Fast Food, Street Food, Momos',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Cool Corner',
#   'Yes',
#   'No',
#   4.2,
#   191,
#   '080 26916505',
#   'Basavanagudi',
#   'Quick Bites',
#   'Masala Dosa, Sandwiches, Coffee, Onion Dosa, Rava Dosa, Chaat, Sandwich',
#   'Street Food, Fast Food',
#   '250',
#   'Delivery',
#   'Banashankari'],
#  ['Pizza Mane',
#   'Yes',
#   'No',
#   3.5,
#   32,
#   '+91 9886212159',
#   'Banashankari',
#   'Quick Bites',
#   'French Fries, Burgers',
#   'Pizza, Sandwich, Burger, Fast Food',
#   '150',
#   'Delivery',
#   'Banashankari'],
#  ['Dal Tadkaa',
#   'Yes',
#   'No',
#   2.5,
#   247,
#   '080 26691763\r\n+91 9620138000',
#   'Banashankari',
#   'Casual Dining',
#   'Paratha, Boondi Raita, Roti, Kulfi, Panneer Butter Masala, Sweet Lassi, Dal Tadka',
#   'North Indian',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Chutney Chang',
#   'Yes',
#   'Yes',
#   4.1,
#   2339,
#   '080 22443007\r\n+91 9901967373',
#   'Jayanagar',
#   'Casual Dining',
#   'Veg Momos, Brownie Chocolate, Palak Chaat, Mutton Biryani, Dahipuri, Fish, Sea Food',
#   'North Indian, Chinese, BBQ',
#   '1,500',
#   'Delivery',
#   'Banashankari'],
#  ['Mystique Palate',
#   'Yes',
#   'No',
#   4.1,
#   337,
#   '+91 9663313544\r\n+91 9916685945',
#   'Jayanagar',
#   'Quick Bites',
#   'Noodles, Pasta, Schezwan Momos, Chicken Momo, Teriyaki Chicken, Thukpa, Fries',
#   'Chinese, Fast Food',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Thamboola',
#   'Yes',
#   'No',
#   3.9,
#   135,
#   '080 26711258\r\n+91 9845154172',
#   'Banashankari',
#   'Casual Dining',
#   'Spring Roll, Manchow Soup, Babycorn Manchurian, Mint Cooler, Roti, Panneer Butter Masala',
#   'North Indian, Chinese, Continental',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['Castle Rock',
#   'Yes',
#   'No',
#   3.6,
#   172,
#   '080 42014000\r\n+91 9845030125',
#   'Uttarahalli',
#   'Casual Dining',
#   'Biryani',
#   'North Indian, Chinese',
#   '700',
#   'Delivery',
#   'Banashankari'],
#  ['Vietnamese Kitchen',
#   'Yes',
#   'No',
#   3.6,
#   105,
#   '080 26697884\r\n080 26697883',
#   'Banashankari',
#   'Casual Dining',
#   'Pho, Papaya Salad, Coffee, Veg Momos, Rolls',
#   'Vietnamese',
#   '700',
#   'Delivery',
#   'Banashankari'],
#  ['Smacznego',
#   'Yes',
#   'No',
#   4.2,
#   504,
#   '+91 9945230807\r\n+91 9743804471',
#   'Banashankari',
#   'Cafe',
#   'Waffles, Pasta, Coleslaw Sandwich, Choco Waffle, Tacos, Momos, Cheese Nachos',
#   'Cafe, Mexican, Italian, Momos, Beverages',
#   '550',
#   'Delivery',
#   'Banashankari'],
#  ['Toscano',
#   'Yes',
#   'Yes',
#   4.3,
#   1129,
#   '080 41558423\r\n+91 7619320074',
#   'Jayanagar',
#   'Casual Dining',
#   'Pizza, Pasta, Salads, Calamari, Ravioli, Pumpkin Soup, Wine',
#   'Italian, Salad',
#   '1,300',
#   'Delivery',
#   'Banashankari'],
#  ['Stoned Monkey',
#   'Yes',
#   'No',
#   4.3,
#   860,
#   '+91 9972710694\r\n+91 9972710894',
#   'Banashankari',
#   'Dessert Parlor',
#   'Nachos, Cup Cake, Hot Chocolate Fudge, Salsa, Cheesy Garlic Bread, Waffles, Tiramisu',
#   'Desserts, Ice Cream',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Central Jail Restaurant',
#   'Yes',
#   'No',
#   3.8,
#   412,
#   '+91 7337886666\r\n+91 8880004992',
#   'Jayanagar',
#   'Casual Dining',
#   'Lime Soda, Manchow Soup, Biryani, Lemon Chicken, Tomato Soup, Butter Naan, Chilli Chicken',
#   'Andhra, Seafood, North Indian, Chinese',
#   '700',
#   'Delivery',
#   'Banashankari'],
#  ['Bella',
#   'Yes',
#   'Yes',
#   3.9,
#   142,
#   '+91 8971285555\r\n080 49709755',
#   'Jayanagar',
#   'Casual Dining',
#   'Murgh Ghee Roast, Fish Fry, Ghee Roast Paneer, Neer Dosa, Appam, Sea Food, Chicken Sukha',
#   'Mangalorean, Seafood, South Indian',
#   '1,000',
#   'Delivery',
#   'Banashankari'],
#  ['New Prashanth Hotel',
#   'Yes',
#   'No',
#   3.6,
#   143,
#   '080 26530150\r\n+91 8861190190',
#   'Jayanagar',
#   'Casual Dining',
#   'Ragi Mudde, Lemon Chicken, Chilli Chicken, Chicken Curry, Mutton Chops, Mutton Biryani',
#   'South Indian, Biryani, Chinese, North Indian',
#   '750',
#   'Delivery',
#   'Banashankari'],
#  ['Karma Kaapi',
#   'Yes',
#   'No',
#   4.4,
#   181,
#   '+91 9380908955\r\n+91 7483024632',
#   'Jayanagar',
#   'Beverage Shop',
#   'Pasta, Potato Fries, Potato Wedges, Hot Chocolate, Chaat, Filter Coffee, Americano',
#   'Beverages, Tea',
#   '250',
#   'Delivery',
#   'Banashankari'],
#  ["Tiwari's",
#   'Yes',
#   'No',
#   3.8,
#   70,
#   '+91 9844733389\r\n+91 7829398815',
#   'Jayanagar',
#   'Quick Bites',
#   'Sweet Lassi, Gulab Jamun, Palak Paneer Paratha, Paneer Parantha',
#   'North Indian, Street Food',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ['Pizza Stop',
#   'Yes',
#   'No',
#   3.8,
#   164,
#   '080 46640404',
#   'Basavanagudi',
#   'Quick Bites',
#   'Pizza, White Sauce Pasta, Masala Garlic Bread',
#   'Pizza, Italian',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ["Biggies Burger 'n' More",
#   'Yes',
#   'No',
#   3.6,
#   58,
#   '+91 9972972950\r\n+91 9663729632',
#   'Kumaraswamy Layout',
#   'Quick Bites',
#   'Burgers, Fries, Mojito, Chicken Burger',
#   'Cafe, Burger, Beverages',
#   '650',
#   'Delivery',
#   'Banashankari'],
#  ["Srinathji's Cafe",
#   'No',
#   'No',
#   3.8,
#   148,
#   '080 26600704\r\n+91 9342593424',
#   'Basavanagudi',
#   'Casual Dining, Cafe',
#   'Paratha, Sandwich, Chilli Idli, Noodles, Sandwiches, Lime Soda',
#   'North Indian, Cafe, Chinese, Fast Food',
#   '550',
#   'Delivery',
#   'Banashankari'],
#  ["Kollapuri's",
#   'No',
#   'No',
#   3.9,
#   206,
#   '080 41205839',
#   'Basavanagudi',
#   'Quick Bites',
#   'Chicken Biryani, Mutton Biryani, Egg Biryani, Chicken Fry, Mutton Fry',
#   'South Indian, Mangalorean',
#   '450',
#   'Delivery',
#   'Banashankari'],
#  ['RS Shiv Sagar',
#   'No',
#   'No',
#   3.7,
#   217,
#   '080 26604686\r\n080 26600115',
#   'Basavanagudi',
#   'Casual Dining',
#   'Chaat, Brownie, Onion Rings, Tomato Soup, Paneer Manchurian, Thali, Faluda',
#   'North Indian, Chinese, South Indian, Fast Food, Juices',
#   '450',
#   'Delivery',
#   'Banashankari'],
#  ['Harshi Super Sandwich',
#   'No',
#   'No',
#   3.8,
#   148,
#   '+91 9900924729',
#   'Basavanagudi',
#   'Quick Bites',
#   'Sandwiches, Chocolate Sandwich, Chaat, Veg Cheese Sandwich, Chilli Cheese, Corn Sandwich',
#   'Fast Food, Street Food',
#   '150',
#   'Delivery',
#   'Banashankari'],
#  ['Ugadi',
#   'Yes',
#   'No',
#   2.9,
#   177,
#   '+91 9742231320',
#   'Jayanagar',
#   'Casual Dining',
#   'Prawn Biryani, Andhra Meal, Veg Thali, Fry Piece Biryani, Gongura Chicken, Paratha',
#   'North Indian, Chinese, Biryani, Andhra, Mangalorean',
#   '700',
#   'Delivery',
#   'Banashankari'],
#  ['Subway',
#   'Yes',
#   'No',
#   3.7,
#   136,
#   '080 42136088\r\n080 26719446',
#   'Banashankari',
#   'Quick Bites',
#   'Veggie Delight, Paneer Tikka, Salad',
#   'Salad, Fast Food',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['The Lassi Park',
#   'Yes',
#   'No',
#   4.1,
#   185,
#   '+91 8095957665',
#   'Jayanagar',
#   'Quick Bites',
#   'Faluda, Brownie, Sandwich, Kulfi, Fruit Salad, Sweet Lassi, Chocolate Fudge',
#   'Juices, Desserts',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ['A2B - Adyar Ananda Bhavan',
#   'Yes',
#   'No',
#   3.8,
#   155,
#   '080 26746999\r\n080 26748999',
#   'Mysore Road',
#   'Casual Dining',
#   'Pav Bhaji, Masala Dosa, Idli Vada, Filter Coffee, Pongal, Curd Rice, Kesari Bath',
#   'South Indian, North Indian, Chinese, Street Food',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Srikrishna Bhavan',
#   'Yes',
#   'No',
#   3.8,
#   42,
#   '+91 9590895055\r\n+91 9845664745',
#   'Banashankari',
#   'Quick Bites',
#   'Roti, Masala Dosa',
#   'South Indian, North Indian, Chinese',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Timepass Dinner',
#   'Yes',
#   'No',
#   3.8,
#   286,
#   '+91 9980040002\r\n+91 9980063005',
#   'Basavanagudi',
#   'Casual Dining',
#   'Onion Rings, Pasta, Kadhai Paneer, Salads, Salad, Roti, Jeera Rice',
#   'North Indian',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['Green Gardenia',
#   'Yes',
#   'No',
#   3.8,
#   160,
#   '080 26698822\r\n+91 9945704570',
#   'Banashankari',
#   'Casual Dining',
#   'Masala Papad, Paneer Satay, Paneer Hyderabadi, Butter Naan, Roti',
#   'North Indian, Chinese',
#   '700',
#   'Delivery',
#   'Banashankari'],
#  ['J Spice',
#   'Yes',
#   'No',
#   3.8,
#   59,
#   '+91 8026739252\r\n+91 9008520007',
#   'Banashankari',
#   'Casual Dining',
#   'Stuffed Mushroom, Chicken Biryani, Jal-jeera',
#   'North Indian, Chinese',
#   '750',
#   'Delivery',
#   'Banashankari'],
#  ['Hatti Kaapi',
#   'Yes',
#   'No',
#   4.0,
#   89,
#   '080 40942666',
#   'Jayanagar',
#   'Quick Bites',
#   'Filter Coffee, Tea, Hot Coffee, Hatti Samosa',
#   'South Indian, Beverages',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ['Upahara Darshini',
#   'Yes',
#   'No',
#   3.9,
#   40,
#   '080 22454581',
#   'Basavanagudi',
#   'Casual Dining',
#   'Masala Dosa',
#   'North Indian, Chinese, South Indian, Fast Food',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['The Chaat Shop',
#   'Yes',
#   'No',
#   2.5,
#   35,
#   '+91 9066510817',
#   'Basavanagudi',
#   'Quick Bites',
#   'Badam Milk, Potato Twister, Pav Bhaji, Panipuri, Tikki Chaat, Cheese Cutlet',
#   'Fast Food',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ['My Tea House',
#   'Yes',
#   'No',
#   3.6,
#   62,
#   '080 65975430\r\n+91 7337733798',
#   'Banashankari',
#   'Quick Bites, Cafe',
#   'Pasta, Iced Tea',
#   'Italian, Fast Food, Cafe, European',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['Samskruti - Sanman Gardenia',
#   'Yes',
#   'No',
#   4.1,
#   139,
#   '080 26570711\r\n+91 9663684499',
#   'Jayanagar',
#   'Casual Dining',
#   'Roti, Butter Kulcha, Fried Rice, Tomato Soup, Curd Rice, Lunch Buffet, Paneer Tikka',
#   'North Indian, Chinese, South Indian',
#   '550',
#   'Delivery',
#   'Banashankari'],
#  ['Chumma Delicious',
#   'Yes',
#   'No',
#   3.7,
#   237,
#   '+91 9341262402\r\n+91 9108648373',
#   'Banashankari',
#   'Quick Bites',
#   'Chicken Biryani',
#   'South Indian, Fast Food',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ['New Prashanth Hotel',
#   'Yes',
#   'No',
#   3.9,
#   388,
#   '080 49569558\r\n+91 8197819686',
#   'Banashankari',
#   'Casual Dining',
#   'Chicken Biryani, Ragi Mudde, Mutton Chops',
#   'Biryani, North Indian, Seafood, Andhra',
#   '650',
#   'Delivery',
#   'Banashankari'],
#  ['Dwaraka Grand',
#   'Yes',
#   'No',
#   3.9,
#   128,
#   '+91 9448214873',
#   'Kumaraswamy Layout',
#   'Casual Dining',
#   'Masala Dosa, Coffee',
#   'South Indian, Chinese, Street Food, Juices',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Gufha - The President Hotel',
#   'Yes',
#   'Yes',
#   4.1,
#   1875,
#   '080 41808777\r\n+91 9900265022',
#   'Jayanagar',
#   'Casual Dining',
#   'Cocktails, Paneer Tikka, Rasmalai, Rabri, Masala Papad, Vegetable Biryani, Chicken Curry',
#   'North Indian, Afghani, Mughlai',
#   '1,200',
#   'Delivery',
#   'Banashankari'],
#  ['Cafe Vivacity',
#   'Yes',
#   'No',
#   3.8,
#   90,
#   '080 26768182\r\n+91 9845704455',
#   'Banashankari',
#   'Cafe',
#   'Garlic Bread, Burgers, Sandwiches, Pizza, Hot Chocolate Fudge, Waffles, Potato Wedges',
#   'Cafe',
#   '650',
#   'Delivery',
#   'Banashankari'],
#  ['Mojo Pizza - 2X Toppings',
#   'Yes',
#   'No',
#   4.2,
#   179,
#   '022 33252828',
#   'Banashankari',
#   'Delivery',
#   'Veggie Pizza, Garlic Bread, Lava Cake, Chocolava, Spicy Paneer',
#   'Pizza',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['South Kitchen',
#   'Yes',
#   'No',
#   4.3,
#   275,
#   '+91 9880980009',
#   'Basavanagudi',
#   'Quick Bites',
#   'Kharabath, Crispy Vada, Filter Coffee, Idli Vada, Idli Chutney, Kesari Bath, Gulab Jamun',
#   'South Indian',
#   '100',
#   'Delivery',
#   'Banashankari'],
#  ['Chung Wah',
#   'Yes',
#   'No',
#   3.7,
#   323,
#   '+91 9108945477\r\n+91 9108945277',
#   'Jayanagar',
#   'Casual Dining',
#   'Noodles, Veg Momos, Chowmein, Schezwan Fried Rice, Clear Soup, Sweet Corn Soup, Chicken Wings',
#   'Chinese, Thai, Momos',
#   '850',
#   'Delivery',
#   'Banashankari'],
#  ['Prems Graama Bhojanam',
#   'Yes',
#   'No',
#   4.3,
#   322,
#   '080 26630542\r\n+91 9611980542',
#   'Jayanagar',
#   'Casual Dining',
#   'Veg Thali, Matka Kulfi, Pongal, Buttermilk, Vada, Ragi Mudde, Curd Rice',
#   'South Indian',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Java City',
#   'Yes',
#   'No',
#   2.6,
#   157,
#   '080 41654693',
#   'Jayanagar',
#   'Cafe',
#   'Coffee, Sandwich, Hot Chocolate, Ice Tea, Sandwiches, Chicken Lasagne, Pizza',
#   'Cafe, American, Pizza',
#   '450',
#   'Delivery',
#   'Banashankari'],
#  ['Kamat Bugle Rock',
#   'Yes',
#   'No',
#   3.9,
#   543,
#   '080 26605734',
#   'Basavanagudi',
#   'Quick Bites',
#   'Jowar Roti, Buttermilk, Jolada Rotti, Brinjal Curry, Coffee, Pongal, Vegetable Biryani',
#   'South Indian, Fast Food',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Woodee Pizza',
#   'Yes',
#   'No',
#   3.7,
#   180,
#   '+91 7406822844',
#   'Banashankari',
#   'Cafe',
#   'Pizza, Garlic Bread',
#   'Cafe, Pizza, Fast Food, Beverages',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Puliyogare Point',
#   'Yes',
#   'No',
#   4.2,
#   444,
#   '+91 9986953484\r\n+91 9880156235',
#   'Basavanagudi',
#   'Quick Bites',
#   'Sweet Pongal, Mini Idlis, Filter Coffee, Open Masala Dosa, Pakoda, Vada, Raagi Dosa',
#   'South Indian',
#   '100',
#   'Delivery',
#   'Banashankari'],
#  ['Bangalore Agarwal Bhavan',
#   'Yes',
#   'No',
#   3.9,
#   134,
#   '+91 9880988500\r\n+91 9342943356',
#   'Jayanagar',
#   'Quick Bites',
#   'Paratha, Coffee, Halwa, Lassi',
#   'Street Food, North Indian, South Indian',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Rustic Stove',
#   'Yes',
#   'No',
#   3.8,
#   577,
#   '080 26547755\r\n+91 9686372742',
#   'Jayanagar',
#   'Casual Dining',
#   'Vegetable Biryani, Pineapple Rasam, Cheese Garlic Naan, Potato Cheese Ball, Bamboo Chicken Biryani, Chicken Skewer, Fish',
#   'North Indian, South Indian, Biryani, Beverages',
#   '900',
#   'Delivery',
#   'Banashankari'],
#  ['De Thaali',
#   'Yes',
#   'No',
#   3.9,
#   144,
#   '080 22445267',
#   'Jayanagar',
#   'Casual Dining',
#   'Malai Kofta, Sandwich, Naan',
#   'North Indian, Chinese, Rolls',
#   '550',
#   'Delivery',
#   'Banashankari'],
#  ['Spice Elephant',
#   'Yes',
#   'No',
#   4.1,
#   787,
#   '080 41714161',
#   'Banashankari',
#   'Casual Dining',
#   'Momos, Lunch Buffet, Chocolate Nirvana, Thai Green Curry, Paneer Tikka, Dum Biryani, Chicken Biryani',
#   'Chinese, North Indian, Thai',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['Matru Sagar',
#   'Yes',
#   'No',
#   3.6,
#   84,
#   '+91 9972368854',
#   'Banashankari',
#   'Quick Bites',
#   'Coffee, Masala Dosa',
#   'South Indian, North Indian, Chinese',
#   '250',
#   'Delivery',
#   'Banashankari'],
#  ['Sea Spice by 7 Star',
#   'Yes',
#   'Yes',
#   4.0,
#   349,
#   '080 49653393',
#   'Banashankari',
#   'Casual Dining',
#   'Sea Food, Neer Dosa, Anjal Masala Fry, Coconut Pudding, Chicken Biryani, Roti, Fish Curry',
#   'Seafood, Biryani, Beverages, South Indian, North Indian, Kebab',
#   '1,200',
#   'Delivery',
#   'Banashankari'],
#  ['Desi Dawat',
#   'Yes',
#   'No',
#   3.7,
#   248,
#   '+91 6363331588',
#   'Kumaraswamy Layout',
#   'Quick Bites',
#   'Tandoori Chicken, Rolls',
#   'North Indian, Fast Food',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Cafe Aira',
#   'Yes',
#   'No',
#   4.1,
#   216,
#   '+91 9980570955\r\n080 41121975',
#   'Basavanagudi',
#   'Cafe',
#   'Pasta, Nachos, Jalapeno Poppers, Burrito Bowl, Ferrero Rocher Shake, Falafal Sandwich, Banana Waffles',
#   'Cafe, Continental, Beverages, Desserts',
#   '500',
#   'Delivery',
#   'Banashankari'],
#  ['Penthouse Cafe',
#   'Yes',
#   'No',
#   4.0,
#   324,
#   '+91 8884135549\r\n+91 9449449316',
#   'Banashankari',
#   'Cafe',
#   'Pizza, Mocktails, Coffee, Nachos, Salad, Pasta, Sandwiches',
#   'Cafe, Italian, Continental',
#   '700',
#   'Delivery',
#   'Banashankari'],
#  ['Mast Punjabi',
#   'Yes',
#   'No',
#   2.6,
#   231,
#   '+91 7338562176',
#   'Kumaraswamy Layout',
#   'Quick Bites',
#   'Aloo Paratha',
#   'North Indian, Chinese, Rolls, Biryani, Kebab',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['South Grand',
#   'Yes',
#   'No',
#   3.4,
#   102,
#   '080 26394647',
#   'Uttarahalli',
#   'Casual Dining',
#   'Rava Dosa',
#   'South Indian, North Indian, Chinese, Beverages',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Catch-up-ino',
#   'Yes',
#   'No',
#   3.9,
#   133,
#   '+91 9972988038\r\n+91 9900121238',
#   'Banashankari',
#   'Cafe',
#   'Momos, Mushroom Bruschettas, Jalapeno Cheeseballs, Pasta, Red Velvet Shake, Red Velvet Milkshake, Maggi',
#   'Cafe, Fast Food, Continental, Chinese, Momos',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['The Pizzeria',
#   'Yes',
#   'No',
#   2.8,
#   45,
#   '+91 9845154172\r\n+91 9620344606',
#   'Banashankari',
#   'Casual Dining',
#   'Pesto Pizza',
#   'Pizza, Italian, Salad',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['Ruchis Point',
#   'Yes',
#   'No',
#   3.8,
#   75,
#   '+91 9901999970',
#   'Banashankari',
#   'Quick Bites',
#   'Sandwiches, Noodles, Sandwich',
#   'Fast Food, Chinese',
#   '200',
#   'Delivery',
#   'Banashankari'],
#  ['Firangi Bake',
#   'Yes',
#   'No',
#   4.0,
#   53,
#   '+91 7710090007',
#   'Rajarajeshwari Nagar',
#   'Delivery',
#   'Lasagne, Steak, Masala Quesadilla, Garlic Bread',
#   'Mexican, Italian',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['The Royal Corner - Pai Viceroy',
#   'Yes',
#   'Yes',
#   4.2,
#   815,
#   '+91 9980909054\r\n+91 9845184810',
#   'Jayanagar',
#   'Casual Dining',
#   'Breakfast Buffet, Kulcha, Almond Soup, Lunch Buffet, Roti, Mocktails, Vegetarian',
#   'North Indian, Chinese',
#   '900',
#   'Delivery',
#   'Banashankari'],
#  ['Hara Fine Dine',
#   'Yes',
#   'Yes',
#   4.0,
#   633,
#   '080 42112211\r\n+91 9880412211',
#   'Banashankari',
#   'Casual Dining',
#   'Hara Bhara Kabab, Crispy Corn, Patiala Paneer, Panneer Butter Masala, Dum Biryani, Jal-jeera, Butter Naan',
#   'North Indian, Chinese',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['Chocoberry',
#   'Yes',
#   'No',
#   3.5,
#   56,
#   '+91 9742644747',
#   'Jayanagar',
#   'Dessert Parlor',
#   'Waffles, Cup Cake, Chocolate Cake',
#   'Ice Cream, Desserts, Beverages',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Waffle-A-Go Go',
#   'Yes',
#   'No',
#   3.9,
#   70,
#   '+91 9900281611',
#   'Banashankari',
#   'Dessert Parlor',
#   'Waffles',
#   'Fast Food, Desserts, Ice Cream',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Cross Road Cafe',
#   'Yes',
#   'No',
#   3.9,
#   91,
#   '080 41247022',
#   'Jayanagar',
#   'Cafe',
#   'Momos, Burgers, Rolls, Sandwich, Hot Chocolate, Tea, Naga Thali',
#   'Cafe, Fast Food, Chinese',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Bakers Town',
#   'Yes',
#   'No',
#   3.8,
#   77,
#   '+91 8884550298',
#   'Kumaraswamy Layout',
#   'Cafe',
#   'Freak Shake, Fries, Pasta Alfredo',
#   'Cafe, Continental, Fast Food',
#   '650',
#   'Delivery',
#   'Banashankari'],
#  ['Ivy',
#   'Yes',
#   'No',
#   3.8,
#   210,
#   '080 42292888',
#   'Kumaraswamy Layout',
#   'Casual Dining',
#   'Butter Chicken, Chicken Grill, Tandoori Chicken, Noodles, Biryani, Fried Rice Chicken',
#   'North Indian, Chinese, Fast Food',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['The Airos',
#   'Yes',
#   'No',
#   4.1,
#   130,
#   '+91 7026390001',
#   'Jayanagar',
#   'Cafe',
#   'Pizza, Pasta, Nachos, Burgers, Sandwich, Tea, Cheese Balls',
#   'Cafe, Italian, Pizza',
#   '650',
#   'Delivery',
#   'Banashankari'],
#  ['Chai Kraft',
#   'Yes',
#   'No',
#   4.1,
#   30,
#   '+91 9946666099',
#   'Jayanagar',
#   'Beverage Shop',
#   'Masala Chai, Coffee, Masala Tea, Maggi',
#   'Beverages, Tea',
#   '100',
#   'Delivery',
#   'Banashankari'],
#  ["Kirthi's Biryani",
#   'Yes',
#   'No',
#   3.8,
#   144,
#   '080 26711554\r\n+91 9741406338',
#   'Banashankari',
#   'Cafe',
#   'Pasta, Gelato, Garlic Bread, Mojito, Nachos, Paneer Pizza, Mocktails',
#   'Chinese, Cafe, Italian',
#   '700',
#   'Delivery',
#   'Banashankari'],
#  ['The Trundle',
#   'Yes',
#   'No',
#   3.7,
#   133,
#   '+91 9986520008',
#   'Jayanagar',
#   'Casual Dining',
#   'Salad, Mocktails, Chocolava, Pesto Pasta, Momos, Jasmine Rice, Tom Yum Soup',
#   'Chinese, Thai, Continental, North Indian',
#   '700',
#   'Delivery',
#   'Banashankari'],
#  ['The Krishna Grand Xpress',
#   'Yes',
#   'No',
#   4.0,
#   136,
#   '+91 9845108265',
#   'Jayanagar',
#   'Quick Bites',
#   'Vada, Masala Dosa, Idli',
#   'South Indian, Fast Food',
#   '350',
#   'Delivery',
#   'Banashankari'],
#  ['Udupi Grand',
#   'Yes',
#   'No',
#   3.8,
#   74,
#   '+91 9242115999\r\n+91 9591322733',
#   'Basavanagudi',
#   'Quick Bites',
#   'Coffee, Masala Dosa, Vegetable Biryani',
#   'South Indian, North Indian, Chinese',
#   '300',
#   'Delivery',
#   'Banashankari'],
#  ['Little Cafe',
#   'Yes',
#   'No',
#   3.7,
#   54,
#   '+91 9741248269',
#   'Basavanagudi',
#   'Cafe',
#   'Pasta, Pizza, Burgers, Pancakes, Garlic Bread',
#   'Cafe, Beverages',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['1980s Games Cafe',
#   'Yes',
#   'No',
#   3.4,
#   58,
#   '080 41677077',
#   'Basavanagudi',
#   'Cafe',
#   'Maggi, Pasta, Burgers, Sandwiches, Fries',
#   'Cafe, Fast Food',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Kadala Tarangaa',
#   'Yes',
#   'No',
#   3.6,
#   129,
#   '+91 9743491480\r\n+91 9483528275',
#   'Banashankari',
#   'Casual Dining',
#   'Sea Food, Neer Dosa',
#   'Mangalorean, Seafood, North Indian',
#   '600',
#   'Delivery',
#   'Banashankari'],
#  ['As On Fire',
#   'Yes',
#   'No',
#   3.5,
#   41,
#   '+91 9731111852',
#   'South Bangalore',
#   'Food Truck',
#   'Pizza',
#   'Pizza, Fast Food, BBQ',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Curry Leaves',
#   'Yes',
#   'No',
#   4.1,
#   176,
#   '+91 8048666976\r\n+91 8026760130',
#   'Basavanagudi',
#   'Casual Dining',
#   'Brownie, Mojito, Prawn Ghee Roast, Corn Tikki, Mushroom Ghee Roast, Pinacolada, Biryani',
#   'Andhra, North Indian, Chinese',
#   '800',
#   'Delivery',
#   'Banashankari'],
#  ['Magic Meals',
#   'Yes',
#   'No',
#   3.7,
#   47,
#   '+91 9986281317\r\n+91 8970050267',
#   'Jayanagar',
#   'Quick Bites, Dessert Parlor',
#   'Biryani, Thick Shakes, Fries',
#   'Fast Food, Desserts, Beverages',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ['Desi Cream Junction',
#   'Yes',
#   'Yes',
#   3.7,
#   36,
#   '+91 9342943356\r\n+91 9880988500',
#   'Jayanagar',
#   'Casual Dining',
#   'Vegetarian',
#   'Chinese, North Indian, Pizza, Italian',
#   '650',
#   'Delivery',
#   'Banashankari'],
#  ['Eat Repeat',
#   'Yes',
#   'No',
#   3.9,
#   101,
#   '+91 9945607074\r\n+91 9880308011',
#   'Basavanagudi',
#   'Quick Bites',
#   'Sweet Pongal, Curd Rice',
#   'South Indian',
#   '150',
#   'Delivery',
#   'Banashankari'],
#  ['Salut',
#   'Yes',
#   'Yes',
#   4.1,
#   442,
#   '+91 8971285555\r\n080 49709755',
#   'Jayanagar',
#   'Pub, Casual Dining',
#   'Pesto Pizza, Buffalo Wings, Cocktails, Beer, Egg Ghee Roast, Brownie, Pepper Chicken',
#   'Continental, Finger Food, Seafood, Pizza',
#   '1,200',
#   'Delivery',
#   'Banashankari'],
#  ["Sandwich Mama's And Frozen Monster",
#   'Yes',
#   'No',
#   3.8,
#   53,
#   '00 09945784161',
#   'Jayanagar',
#   'Quick Bites',
#   'Waffles, Sandwiches, Maggi, Thick Shakes, Chocolate Sandwich',
#   'Ice Cream, Beverages, Fast Food',
#   '250',
#   'Delivery',
#   'Banashankari'],
#  ['Food Springs',
#   'Yes',
#   'No',
#   4.0,
#   232,
#   '080 42010153',
#   'Jayanagar',
#   'Quick Bites',
#   'Honey Chilli Potatoes, Nachos, Lemonade, Hakka Noodles, Babycorn Manchurian, Mushroom Manchurian, Spring Roll',
#   'South Indian, Chinese',
#   '400',
#   'Delivery',
#   'Banashankari'],
#  ["Chung's Chinese Corner",
#   'Yes',
#   'No',
#   3.9,
#   221,
#   '080 26644700\r\n080 41211700',
#   'Jayanagar',
#   'Casual Dining',
#   'Manchow Soup, Momos, Wonton Soup, Chowmein, American Chopsuey, Chop Suey, Manchurian',
#   'Chinese',
#   '700',
#   'Delivery',
#   'Banashankari'],
#  ['Eurasia Pasta and Barbeque by Little Italy',
#   'Yes',
#   'Yes',
#   4.1,
#   1063,
#   '080 22452202\r\n080 22452203',
#   'Jayanagar',
#   'Casual Dining, Bar',
#   'Pasta, Pizza, Nachos, Gelato, Ravioli, Jalapeno Poppers, Cocktails',
#   'Italian, Fast Food, Salad, BBQ',
#   '1,200',
#   'Delivery',
#   'Banashankari'],
#  ['Goli Vada Pav No. 1',
#   'Yes',
#   'No',
# ...
#   'Basavanagudi',
#   'Cafe',
#   'Pasta, Nachos, Jalapeno Poppers, Burrito Bowl, Ferrero Rocher Shake, Falafal Sandwich, Banana Waffles',
#   'Cafe, Continental, Beverages, Desserts',
#   '500',
#   'Cafes',
#   'Basavanagudi'],
#  ['Cafe Mondo',
#   'Yes',
#   'No',
#   3.7,
#   514,
#   '080 42088686',
#   'Basavanagudi',
#   'Cafe',
#   'Pizza, Pasta Alfredo, Brownie, Garlic Bread, Sandwiches, Lemon Mojito, Mocha Fudge',
#   'Cafe, Italian, Beverages',
#   '600',
#   'Cafes',
#   'Basavanagudi'],
#  ['1980s Games Cafe',
#   'Yes',
#   'No',
#   3.4,
#   58,
#   '080 41677077',
#   'Basavanagudi',
#   'Cafe',
#   'Maggi, Pasta, Burgers, Sandwiches, Fries',
#   'Cafe, Fast Food',
#   '400',
#   'Cafes',
#   'Basavanagudi'],
#  ['Go Native',
#   'Yes',
#   'Yes',
#   4.3,
#   1252,
#   '080 49653539',
#   'Jayanagar',
#   'Casual Dining, Cafe',
#   'Mushroom Soup, Salads, Halwa, Thali, Salad, Millet Pizza, Misal Pav',
#   'Healthy Food, Cafe, Beverages',
#   '800',
#   'Cafes',
#   'Basavanagudi'],
#  ['Alchemy Coffee Roasters',
#   'No',
#   'No',
#   4.2,
#   704,
#   '+91 8762473937',
#   'Jayanagar',
#   'Cafe',
#   'Coffee, Fries, Sandwich, Pizza, Pancakes, Pasta, Hot Chocolate',
#   'Cafe',
#   '500',
#   'Cafes',
#   'Basavanagudi'],
#  ['Rooftop Cafe',
#   'Yes',
#   'No',
#   4.1,
#   796,
#   '080 26544411\r\n+91 8050712836',
#   'Jayanagar',
#   'Cafe',
#   'Pizza, Nachos, Rolls, Veggie Roll, Sandwiches, Burgers, Mango Shake',
#   'Cafe, Fast Food, Beverages',
#   '400',
#   'Cafes',
#   'Basavanagudi'],
#  ['Enerjuvate Studio & Cafe',
#   'No',
#   'Yes',
#   4.2,
#   731,
#   '080 41462929\r\n+91 8598866594',
#   'Jayanagar',
#   'Cafe',
#   'Pizza, Vegetarian, Momo Platter, Momos, Nachos, Salsa, Salad',
#   'Cafe, Continental, Beverages, Healthy Food, Desserts, Sandwich, Pizza, Salad',
#   '800',
#   'Cafes',
#   'Basavanagudi'],
#  ['The Caramelts Cafe',
#   'No',
#   'No',
#   4.2,
#   223,
#   '080 26544799',
#   'Jayanagar',
#   'Cafe',
#   'Burgers, Coffee, Pasta, Peri Peri Fries, Kit Kat Shake, Nachos, Paneer Tikka Pizza',
#   'Cafe, Salad, Wraps, Beverages',
#   '800',
#   'Cafes',
#   'Basavanagudi'],
#  ['SlimSins Cafe',
#   'No',
#   'No',
#   4.1,
#   707,
#   '+91 9535582766',
#   'Jayanagar',
#   'Cafe',
#   'Hummus Platter, Juicy Lamb Burger, Salmon Steak, Mousse, Pasta, Pizza, Sweet Potato Fries',
#   'Cafe, Healthy Food',
#   '850',
#   'Cafes',
#   'Basavanagudi'],
#  ['Cafe Ajfan',
#   'Yes',
#   'No',
#   4.2,
#   261,
#   '+91 7022022107\r\n+91 9606791771',
#   'Jayanagar',
#   'Cafe',
#   'Sandwiches, Pasta, Cobb Salad, Pizza, Burgers, Calzone, Fries',
#   'Cafe, Continental, Beverages',
#   '700',
#   'Cafes',
#   'Basavanagudi'],
#  ['Cafe Shuffle',
#   'Yes',
#   'Yes',
#   4.2,
#   150,
#   '+91 9742166777',
#   'Banashankari',
#   'Cafe',
#   'Mocktails, Peri Fries, Lasagne, Pizza, Chicken Bbq Wings, Virgin Mojito, Nachos',
#   'Cafe, Italian, Continental',
#   '600',
#   'Cafes',
#   'Basavanagudi'],
#  ['Krazzy Folds',
#   'Yes',
#   'Yes',
#   4.2,
#   1901,
#   '080 49652953',
#   'Jayanagar',
#   'Cafe',
#   'Pasta, Tacos, Macaroni, Panna Cotta, Salads, Spaghetti, Churros',
#   'Cafe, Continental, Sandwich, Beverages',
#   '800',
#   'Cafes',
#   'Basavanagudi'],
#  ['Penthouse Cafe',
#   'Yes',
#   'No',
#   4.0,
#   324,
#   '+91 8884135549\r\n+91 9449449316',
#   'Banashankari',
#   'Cafe',
#   'Pizza, Mocktails, Coffee, Nachos, Salad, Pasta, Sandwiches',
#   'Cafe, Italian, Continental',
#   '700',
#   'Cafes',
#   'Basavanagudi'],
#  ['The Blue Wagon - Kitchen',
#   'Yes',
#   'No',
#   4.6,
#   228,
#   '+91 8105485007\r\n+91 8095904280',
#   'Jayanagar',
#   'Cafe',
#   'Pizza, Nachos, Garlic Maggi, Burgers, Cheese Maggi, Bruschetta Bites, Sandwich',
#   'Cafe, Beverages',
#   '400',
#   'Cafes',
#   'Basavanagudi'],
#  ['Smacznego',
#   'Yes',
#   'No',
#   4.2,
#   504,
#   '+91 9945230807\r\n+91 9743804471',
#   'Banashankari',
#   'Cafe',
#   'Waffles, Pasta, Coleslaw Sandwich, Choco Waffle, Tacos, Momos, Cheese Nachos',
#   'Cafe, Mexican, Italian, Momos, Beverages',
#   '550',
#   'Cafes',
#   'Basavanagudi'],
#  ['The Airos',
#   'Yes',
#   'No',
#   4.1,
#   130,
#   '+91 7026390001',
#   'Jayanagar',
#   'Cafe',
#   'Pizza, Pasta, Nachos, Burgers, Sandwich, Tea, Cheese Balls',
#   'Cafe, Italian, Pizza',
#   '650',
#   'Cafes',
#   'Basavanagudi'],
#  ['San Churro Cafe',
#   'Yes',
#   'No',
#   3.8,
#   918,
#   '+91 9663487993',
#   'Banashankari',
#   'Cafe, Casual Dining',
#   'Churros, Cannelloni, Minestrone Soup, Hot Chocolate, Pink Sauce Pasta, Salsa, Veg Supreme Pizza',
#   'Cafe, Mexican, Italian',
#   '800',
#   'Cafes',
#   'Basavanagudi'],
#  ['Cafe Vivacity',
#   'Yes',
#   'No',
#   3.8,
#   90,
#   '080 26768182\r\n+91 9845704455',
#   'Banashankari',
#   'Cafe',
#   'Garlic Bread, Burgers, Sandwiches, Pizza, Hot Chocolate Fudge, Waffles, Potato Wedges',
#   'Cafe',
#   '650',
#   'Cafes',
#   'Basavanagudi'],
#  ["Kirthi's Biryani",
#   'Yes',
#   'No',
#   3.8,
#   144,
#   '080 26711554\r\n+91 9741406338',
#   'Banashankari',
#   'Cafe',
#   'Pasta, Gelato, Garlic Bread, Mojito, Nachos, Paneer Pizza, Mocktails',
#   'Chinese, Cafe, Italian',
#   '700',
#   'Cafes',
#   'Basavanagudi'],
#  ['La Grande Cafe',
#   'No',
#   'No',
#   3.8,
#   46,
#   '+91 9845525205',
#   'Jayanagar',
#   'Cafe',
#   'Coffee, Hot Chocolate, Cappuccino, Ice Tea, Corn Balls',
#   'Cafe',
#   '400',
#   'Cafes',
#   'Basavanagudi'],
#  ['4th Tea Block',
#   'No',
#   'No',
#   4.0,
#   62,
#   '+91 9844033353\r\n+91 6361276770',
#   'Jayanagar',
#   'Cafe',
#   'Rose Tea, Hibiscus Tea, Masala Chai, Ginger Tea',
#   'Cafe',
#   '150',
#   'Cafes',
#   'Basavanagudi'],
#  ['Grazers',
#   'Yes',
#   'Yes',
#   3.9,
#   291,
#   '080 26650668',
#   'Jayanagar',
#   'Cafe',
#   'Burgers, Panneer Butter Masala, Pasta, Hot Dog, Fries, Cheesy Pizza, Potato Wedges',
#   'Cafe, Burger, Continental, Italian, Desserts',
#   '650',
#   'Cafes',
#   'Basavanagudi'],
#  ['Cuppa',
#   'No',
#   'No',
#   3.2,
#   59,
#   '080 26564445\r\n+91 9986833382',
#   'Jayanagar',
#   'Cafe, Casual Dining',
#   'Coffee, Sandwich',
#   'Cafe, Fast Food',
#   '550',
#   'Cafes',
#   'Basavanagudi'],
#  ['Brews N Bites',
#   'Yes',
#   'No',
#   2.9,
#   62,
#   '+91 9886791151\r\n+91 9886439454',
#   'Jayanagar',
#   'Quick Bites, Cafe',
#   'Coffee, Cappuccino',
#   'Chinese, Fast Food, Cafe',
#   '650',
#   'Cafes',
#   'Basavanagudi'],
#  ['Java City',
#   'Yes',
#   'No',
#   2.6,
#   157,
#   '080 41654693',
#   'Jayanagar',
#   'Cafe',
#   'Coffee, Sandwich, Hot Chocolate, Ice Tea, Sandwiches, Chicken Lasagne, Pizza',
#   'Cafe, American, Pizza',
#   '450',
#   'Cafes',
#   'Basavanagudi'],
#  ['People Tree Cafe',
#   'No',
#   'No',
#   3.7,
#   168,
#   '+91 9886086452',
#   'Jayanagar',
#   'Cafe',
#   'Chocolate Shake, Nachos, Babycorn Manchurian, Cheese Maggi, French Fries, Tea, Oreo Shake',
#   'Cafe, Fast Food, Beverages',
#   '400',
#   'Cafes',
#   'Basavanagudi'],
#  ['FreshMenu',
#   'Yes',
#   'No',
#   3.9,
#   627,
#   '080 40424242',
#   'Banashankari',
#   'Delivery',
#   'Salads, Sandwiches, Salad, Thai Rice, Pasta, Noodles, Pizza',
#   'Healthy Food, Chinese, Biryani, North Indian, Continental, Salad, American, Burger',
#   '450',
#   'Delivery',
#   'Basavanagudi'],
#  ['Leon Grill',
#   'Yes',
#   'No',
#   4.1,
#   414,
#   '+91 9972001409\r\n+91 7349482017',
#   'Jayanagar',
#   'Quick Bites',
#   'Burgers, Fries, Chicken Filet Burger, Peri Peri Chicken Wings, Peri Peri Chicken Salad, Peri Peri Chicken Burger, Falafel',
#   'Burger, Turkish, Arabian, Fast Food, Salad, Healthy Food, Desserts',
#   '500',
#   'Delivery',
#   'Basavanagudi'],
#  ['Dr. Bubbles',
#   'Yes',
#   'No',
#   4.2,
#   95,
#   '00 8197222666\r\n080 43026625',
#   'Jayanagar',
#   'Beverage Shop, Dessert Parlor',
#   'Waffles, Iced Coffee, Yoghurt Shake, Belgian Chocolate Waffle, Ice Tea, Faluda',
#   'Beverages, Desserts',
#   '400',
#   'Delivery',
#   'Basavanagudi'],
#  ['Empire Restaurant',
#   'Yes',
#   'No',
#   4.4,
#   4884,
#   '080 49653266',
#   'Jayanagar',
#   'Casual Dining',
#   'Chicken Tikka Masala, Mutton Keema Dosa, Mutton Biryani, Raan Biryani, Brain Fry, Chicken Grill, Ghee Rice',
#   'North Indian, Mughlai, South Indian, Chinese',
#   '750',
#   'Delivery',
#   'Basavanagudi'],
#  ['Anna Kuteera',
#   'Yes',
#   'No',
#   4.0,
#   771,
#   '+91 9620009302',
#   'Banashankari',
#   'Casual Dining',
#   'Panner Tikka, Kulfi, Coffee, Pav Bhaji, Carrot Halwa, Fried Rice, Set Dosa',
#   'South Indian, North Indian, Chinese',
#   '450',
#   'Delivery',
#   'Basavanagudi'],
#  ['Energy Addaa',
#   'Yes',
#   'No',
#   4.2,
#   64,
#   '080 49652857',
#   'Basavanagudi',
#   'Quick Bites',
#   'Pizza, Nachos, Salads, Peri Peri Fries, Brownie, Pasta Alfredo, Spaghetti',
#   'Salad, Healthy Food, Sandwich, Juices, Burger, Desserts, Pizza',
#   '500',
#   'Delivery',
#   'Basavanagudi'],
#  ['Dev Sagar - Food Street',
#   'Yes',
#   'No',
#   4.1,
#   233,
#   '+91 9886204745\r\n0161 26624745',
#   'Basavanagudi',
#   'Quick Bites',
#   'Chaat, Pav Bhaji, Dabeli, Vada Pav, Tawa Pulav, Panipuri, Malpua',
#   'Street Food',
#   '200',
#   'Delivery',
#   'Basavanagudi'],
#  ['KFC',
#   'Yes',
#   'No',
#   3.8,
#   505,
#   '080 33994444',
#   'Banashankari',
#   'Quick Bites',
#   'Burgers, French Fries',
#   'Burger, Fast Food',
#   '450',
#   'Delivery',
#   'Basavanagudi'],
#  ['Bengaluru Coffee House',
#   'Yes',
#   'No',
#   4.1,
#   201,
#   '+91 9740180090',
#   'Banashankari',
#   'Quick Bites',
#   'Masala Dosa, Tirupathi Pongal, Filter Coffee, Vada, Kharabath, Kali Dosa, Rava Idli',
#   'South Indian, North Indian, Chinese, Street Food',
#   '300',
#   'Delivery',
#   'Basavanagudi'],
#  ['Shanmukha',
#   'Yes',
#   'No',
#   4.0,
#   774,
#   '080 49652639',
#   'Koramangala 5th Block',
#   'Casual Dining',
#   'Chicken Dum Biryani, Kerala Parotta, Chicken Boneless Biryani, Vegetable Biryani, Naan, Fish, Gulab Jamun',
#   'Biryani, Andhra, North Indian, Chinese',
#   '800',
#   'Delivery',
#   'Basavanagudi'],
#  ['Bhukkhad Baba',
#   'Yes',
#   'No',
#   3.7,
#   125,
#   '+91 6361316696',
#   'JP Nagar',
#   'Quick Bites',
#   'Paratha, Thali',
#   'North Indian, Beverages',
#   '250',
#   'Delivery',
#   'Basavanagudi'],
#  ['House Of Kebabs',
#   'Yes',
#   'No',
#   3.8,
#   540,
#   '080 49653042',
#   'Basavanagudi',
#   'Casual Dining',
#   'Rolls, Shawarma, Butter Chicken, Mutton Biryani, Lahori Chicken, Chicken Roll, Grape Juice',
#   'North Indian, Kebab, Biryani, Chinese',
#   '650',
#   'Delivery',
#   'Basavanagudi'],
#  ['Subway',
#   'Yes',
#   'No',
#   3.7,
#   176,
#   '080 41400246\r\n+91 7829932492',
#   'Basavanagudi',
#   'Quick Bites',
#   'Chocolate Cookies, Mexican Patty',
#   'Salad, Fast Food',
#   '600',
#   'Delivery',
#   'Basavanagudi'],
#  ['Smoke-A-Pot',
#   'Yes',
#   'No',
#   3.6,
#   91,
#   '080 49652493',
#   'JP Nagar',
#   'Takeaway, Delivery',
#   'Pot Biryani, Raita, Mutton Biryani',
#   'Biryani, North Indian, Rolls',
#   '500',
#   'Delivery',
#   'Basavanagudi'],
#  ['Chaatimes',
#   'Yes',
#   'No',
#   3.8,
#   133,
#   '+91 8884232233',
#   'Basavanagudi',
#   'Quick Bites',
#   'Dabeli, Faluda, Masala Poori, Sandwiches, Tokri Chaat, Pav Bhaji, Dahipuri',
#   'Street Food, Fast Food',
#   '200',
#   'Delivery',
#   'Basavanagudi'],
#  ['Wamama',
#   'Yes',
#   'Yes',
#   4.2,
#   354,
#   '+91 8042111599\r\n+91 8971818009',
#   'Banashankari',
#   'Casual Dining',
#   'Sushi, Noodles, Wine, Khau Suey, Mocktails, Yakisoba, Spring Roll',
#   'Asian, Korean, Indonesian, Japanese, Chinese, Thai, Momos',
#   '800',
#   'Delivery',
#   'Basavanagudi'],
#  ['Shanthi Sagar',
#   'Yes',
#   'No',
#   3.6,
#   518,
#   '+91 8217521220',
#   'JP Nagar',
#   'Casual Dining',
#   'Coffee, Mushroom Masala, Masala Dosa, Palak Paneer',
#   'South Indian, North Indian, Chinese',
#   '400',
#   'Delivery',
#   'Basavanagudi'],
#  ['Smacznego',
#   'Yes',
#   'No',
#   4.2,
#   504,
#   '+91 9945230807\r\n+91 9743804471',
#   'Banashankari',
#   'Cafe',
#   'Waffles, Pasta, Coleslaw Sandwich, Choco Waffle, Tacos, Momos, Cheese Nachos',
#   'Cafe, Mexican, Italian, Momos, Beverages',
#   '550',
#   'Delivery',
#   'Basavanagudi'],
#  ['Kabab Magic',
#   'Yes',
#   'No',
#   4.1,
#   1720,
#   '080 26570381',
#   'Basavanagudi',
#   'Quick Bites',
#   'Grape Juice, Chicken Grill, Chicken Tikka Roll, Shawarma Roll, Chicken Shawarama, Biryani Combo, Rolls',
#   'North Indian, Kebab, Chinese, Fast Food',
#   '400',
#   'Delivery',
#   'Basavanagudi'],
#  ['Lassi Corner',
#   'Yes',
#   'No',
#   3.7,
#   107,
#   '+91 9972348689\r\n+91 7204756477',
#   'Basavanagudi',
#   'Beverage Shop',
#   'Lassi',
#   'Beverages, Ice Cream',
#   '150',
#   'Delivery',
#   'Basavanagudi'],
#  ['The Biriyani Pedia',
#   'Yes',
#   'No',
#   3.9,
#   55,
#   '+91 9809202588',
#   'BTM',
#   'Quick Bites',
#   'Chicken Stew, Ghee Rice, Biryani, Chai',
#   'Biryani',
#   '300',
#   'Delivery',
#   'Basavanagudi'],
#  ['Paratha Junction',
#   'Yes',
#   'No',
#   3.2,
#   395,
#   '+91 7022586895',
#   'Jayanagar',
#   'Quick Bites',
#   'Paratha',
#   'North Indian, Chinese',
#   '300',
#   'Delivery',
#   'Basavanagudi'],
#  ['SL Vadapav',
#   'Yes',
#   'No',
#   4.0,
#   78,
#   '+91 9900597313',
#   'Jayanagar',
#   'Quick Bites',
#   'Dabeli, Samosa, Tawa Pulav, Cheese Vada Pav',
#   'Maharashtrian',
#   '100',
#   'Delivery',
#   'Basavanagudi'],
#  ['Adithya',
#   'Yes',
#   'No',
#   4.0,
#   332,
#   '080 49652760',
#   'JP Nagar',
#   'Quick Bites',
#   'Neer Dosa, Coffee, Pav Bhaji, Khali Dosa, Panipuri, Masala Dosa, Tea',
#   'South Indian, North Indian, Chinese',
#   '300',
#   'Delivery',
#   'Basavanagudi'],
#  ['Paradise',
#   'Yes',
#   'No',
#   4.0,
#   1975,
#   '+91 9513477574\r\n+91 9901842605',
#   'JP Nagar',
#   'Casual Dining',
#   'Kalmi Kabab, Hyderabadi Dum Biryani, Vegetable Biryani, Haleem, Supreme Mutton Biryani, Paneer Tikka, Hyderabadi Mutton Biryani',
#   'Biryani, North Indian, Kebab',
#   '800',
#   'Delivery',
#   'Basavanagudi'],
#  ['Biryanis And More',
#   'Yes',
#   'No',
#   4.0,
#   618,
#   '080 48542442\r\n+91 7337271771',
#   'Jayanagar',
#   'Casual Dining',
#   'Prawn Biryani, Dragon Chicken, Chicken Boneless Biryani, Afghani Biryani, Mughlai Biryani, Paneer Tikka Biryani, Gongura Biryani',
#   'Biryani, North Indian, Chinese, Andhra, South Indian',
#   '750',
#   'Delivery',
#   'Basavanagudi'],
#  ["Wazir's",
#   'Yes',
#   'No',
#   3.3,
#   261,
#   '080 22292668\r\n080 41145555',
#   'Shanti Nagar',
#   'Casual Dining',
#   'Biryani, Butter Chicken, Butter Naan, Kalmi Kebab, Roti, Rolls, Fried Rice',
#   'North Indian, Chinese',
#   '500',
#   'Delivery',
#   'Basavanagudi'],
#  ['Krispy Kreme',
#   'Yes',
#   'No',
#   4.0,
#   253,
#   '080 41718398',
#   'Jayanagar',
#   'Dessert Parlor',
#   'Coffee, Chocolate Donut, Chocolate Dreamcake, Cookie Crunch, Double Chocolate Cake, Hot Chocolate',
#   'Desserts, Beverages',
#   '300',
#   'Delivery',
#   'Basavanagudi'],
#  ['Roti Ghar',
#   'Yes',
#   'No',
#   3.9,
#   750,
#   '080 26629734\r\n+91 9880141967',
#   'Basavanagudi',
#   'Casual Dining',
#   'Coffee, Spring Roll, Roti, Panneer Butter Masala, Noodles, Butter Naan, Masala Dosa',
#   'North Indian, Chinese, South Indian',
#   '500',
#   'Delivery',
#   'Basavanagudi'],
#  ['Onesta',
#   'Yes',
#   'Yes',
#   4.6,
#   2556,
#   '080 48653961\r\n080 48655715',
#   'Banashankari',
#   'Casual Dining, Cafe',
#   'Farmhouse Pizza, Chocolate Banana, Virgin Mojito, Pasta, Paneer Tikka, Lime Soda, Prawn Pizza',
#   'Pizza, Cafe, Italian',
#   '600',
#   'Delivery',
#   'Basavanagudi'],
#  ['Keventers',
#   'Yes',
#   'No',
#   3.9,
#   210,
#   '080 49653086',
#   'Jayanagar',
#   'Beverage Shop, Dessert Parlor',
#   'Thick Shakes, Chocolate Hazelnut Shake, Mango Shake, Choco Hazelnut, Milk Shake, Chocolate Oreo, Strawberry Milkshake',
#   'Desserts, Beverages, Ice Cream',
#   '400',
#   'Delivery',
#   'Basavanagudi'],
#  ['Polar Bear',
#   'Yes',
#   'No',
#   3.8,
#   71,
#   '080 49652725',
#   'Basavanagudi',
#   'Dessert Parlor',
#   'Hot Chocolate Fudge',
#   'Ice Cream, Desserts, Beverages, Sandwich',
#   '400',
#   'Delivery',
#   'Basavanagudi'],
#  ['Behrouz Biryani',
#   'Yes',
#   'No',
#   3.9,
#   230,
#   '+91 7022260661\r\n+91 7022260662',
#   'Banashankari',
#   'Delivery',
#   'Raita, Gulab Jamun, Paneer Biryani, Vegetable Biryani, Gosht Dum Biryani, Chicken Biryani, Murgh Biryani',
#   'Biryani',
#   '650',
#   'Delivery',
#   'Basavanagudi'],
#  ['Puliyogare Point',
#   'Yes',
#   'No',
#   4.2,
#   444,
#   '+91 9986953484\r\n+91 9880156235',
#   'Basavanagudi',
#   'Quick Bites',
#   'Sweet Pongal, Mini Idlis, Filter Coffee, Open Masala Dosa, Pakoda, Vada, Raagi Dosa',
#   'South Indian',
#   '100',
#   'Delivery',
#   'Basavanagudi'],
#  ["Kedia's Fun Food",
#   'Yes',
#   'No',
#   4.3,
#   630,
#   '+91 8867769557',
#   'Jayanagar',
#   'Quick Bites',
#   'Paratha, Vada Pav, Chaat, Pav Bhaji, Panipuri, Masala Poori, Dhokla',
#   'North Indian, Street Food, Juices',
#   '200',
#   'Delivery',
#   'Basavanagudi'],
#  ['Sri Udupi Food Hub',
#   'Yes',
#   'Yes',
#   4.1,
#   175,
#   '+91 9916866033',
#   'Jayanagar',
#   'Casual Dining',
#   'Filter Coffee, Masala Dosa, Idli, Vada',
#   'South Indian, North Indian, Chinese, Beverages',
#   '500',
#   'Delivery',
#   'Basavanagudi'],
#  ...]

# %%
# Create a table

mycursor.execute("""CREATE TABLE if not EXISTS Restaurant_Data (

                 name VARCHAR(100) NOT NULL,
                 online_order VARCHAR(50),
                 book_table VARCHAR(50),
                 rate DECIMAL(3,1),
                 votes INT,
                 phone VARCHAR (50),
                 location VARCHAR(100),
                 rest_type VARCHAR(100),
                 dish_liked TEXT,
                 cuisines VARCHAR(300),
                 approx_cost DECIMAL(10,2),
                 listed_type VARCHAR(100),
                 listed_city VARCHAR (100)

                 )""")
conn.commit()

# %%
# Insert data into table

query = """INSERT INTO Restaurant_Data
(name, online_order, book_table, rate, votes,
phone, location, rest_type, dish_liked, cuisines,
approx_cost, listed_type, listed_city)
VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"""

mycursor.executemany(query,data)
conn.commit()

# %%
# Select entire data

import pandas as pd

query = "SELECT * FROM Restaurant_Data"
df = pd.read_sql_query(query, conn)
df
# Out:
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 23153                                 Izakaya Gastro Pub          Yes
# 23154        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 23155                             Keys Cafe - Keys Hotel           No
# 23156                                            Bhagini           No
# 23157  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table  rate  votes                             phone  \
# 0            Yes   4.1    775    080 42297555\r\n+91 9743772233
# 1             No   4.1    787                      080 41714161
# 2             No   3.8    918                    +91 9663487993
# 3             No   3.7     88                    +91 9620009302
# 4             No   3.8    166  +91 8026612447\r\n+91 9901210005
# ...          ...   ...    ...                               ...
# 23153        Yes   3.8    128    +91 7625087121\n+91 8050587483
# 23154         No   3.9     77                      080 49435000
# 23155         No   2.8    161      080 39451000\n+91 8884038484
# 23156         No   2.5     81                      080 65951222
# 23157        Yes   4.3    236                      080 49652769
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# ...                           ...                  ...
# 23153                  Whitefield   Bar, Casual Dining
# 23154                  Whitefield     Fine Dining, Bar
# 23155                  Whitefield   Casual Dining, Bar
# 23156                  Whitefield   Casual Dining, Bar
# 23157  ITPL Main Road, Whitefield                  Bar
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 23153  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 23154                                   Rooftop Ambience
# 23155  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 23156                               Biryani, Andhra Meal
# 23157                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines approx_cost    listed_type  \
# 0                   North Indian, Mughlai, Chinese         800         Buffet
# 1                      Chinese, North Indian, Thai         800         Buffet
# 2                           Cafe, Mexican, Italian         800         Buffet
# 3                       South Indian, North Indian         300         Buffet
# 4                         North Indian, Rajasthani         600         Buffet
# ...                                            ...         ...            ...
# 23153     North Indian, Continental, Mediterranean       1,200  Pubs and bars
# 23154                                  Finger Food       2,000  Pubs and bars
# 23155           Chinese, Continental, North Indian       1,200  Pubs and bars
# 23156  Andhra, South Indian, Chinese, North Indian         800  Pubs and bars
# 23157                                  Finger Food       2,500  Pubs and bars
#
#         listed_city
# 0      Banashankari
# 1      Banashankari
# 2      Banashankari
# 3      Banashankari
# 4      Banashankari
# ...             ...
# 23153    Whitefield
# 23154    Whitefield
# 23155    Whitefield
# 23156    Whitefield
# 23157    Whitefield
#
# [23158 rows x 13 columns]

# %%
# Applying filters for the given data

query = """SELECT *
FROM Restaurant_Data
WHERE
online_order = 'Yes' AND
rest_type = 'Delivery' AND
approx_cost < 500 AND
votes < 400 AND
listed_type = 'Delivery'
"""
df = pd.read_sql_query(query, conn)
df
# Out:
#                   name online_order book_table  rate  votes  \
# 0            Mealer.in          Yes         No   4.0    205
# 1      Calorie Express          Yes         No   3.6    192
# 2    Rithika's Kitchen          Yes         No   3.8    106
# 3        Dream a Dozen          Yes         No   4.3    133
# 4            FreshMenu          Yes         No   3.2    113
# ..                 ...          ...        ...   ...    ...
# 176          Bonfooder          Yes         No   3.8     36
# 177      Kerala Tiffin          Yes         No   3.9    167
# 178    Techies Kitchen          Yes         No   3.5    197
# 179               KA53          Yes         No   3.9     45
# 180   Office Lunch Box          Yes         No   3.6    114
#
#                                   phone                    location rest_type  \
# 0      080 48542046\r\r\n+91 9513771133                    JP Nagar  Delivery
# 1                        +91 9663868626                         BTM  Delivery
# 2    +91 9901468279\r\r\n+91 8904588050                    JP Nagar  Delivery
# 3                        +91 8861739269                    JP Nagar  Delivery
# 4                          080 40424242                Marathahalli  Delivery
# ..                                  ...                         ...       ...
# 176                      +91 8884532555               Sarjapur Road  Delivery
# 177                      +91 7907943091                  Whitefield  Delivery
# 178                      +91 9880329528  ITPL Main Road, Whitefield  Delivery
# 179                        080 49652151                  Whitefield  Delivery
# 180      +91 7338220909\n+91 7338220808                  Whitefield  Delivery
#
#                                             dish_liked  \
# 0          Rajma, Dal Makhani, Kadhi Chawal, Dal Tadka
# 1                                     Chicken Sandwich
# 2    Mutton Curry, Chicken Fry, Chicken Biryani, Ch...
# 3    Cup Cake, Cake Pops, Chocolate Truffle Cake, B...
# 4                                     Biryani, Burgers
# ..                                                 ...
# 176                                 Dahi Bhalle, Thali
# 177                                              Appam
# 178                      Chicken Biryani, Aloo Paratha
# 179  Paneer Pasanda, Panneer Butter Masala, Murgh P...
# 180                                      Chicken Curry
#
#                                               cuisines  approx_cost  \
# 0                                North Indian, Biryani          450
# 1                                         Healthy Food          450
# 2                        Biryani, South Indian, Andhra          350
# 3                                     Bakery, Desserts          300
# 4    Healthy Food, Chinese, Biryani, North Indian, ...          450
# ..                                                 ...          ...
# 176                                       North Indian          400
# 177                                             Kerala          300
# 178                              Biryani, North Indian          400
# 179                              North Indian, Chinese          300
# 180                               Andhra, North Indian          200
#
#     listed_type        listed_city
# 0      Delivery  Bannerghatta Road
# 1      Delivery  Bannerghatta Road
# 2      Delivery  Bannerghatta Road
# 3      Delivery  Bannerghatta Road
# 4      Delivery          Bellandur
# ..          ...                ...
# 176    Delivery      Sarjapur Road
# 177    Delivery         Whitefield
# 178    Delivery         Whitefield
# 179    Delivery         Whitefield
# 180    Delivery         Whitefield
#
# [181 rows x 13 columns]

# %%
# 1. Which Bangalore locations have the highest average restaurant ratings?

query = """SELECT
location, AVG(rate) as AVG_Rating
FROM Restaurant_Data
GROUP BY location
ORDER BY AVG_Rating DESC
LIMIT 15
"""
df = pd.read_sql_query(query, conn)
df
# Out:
#                  location  AVG_Rating
# 0            Lavelle Road    4.192534
# 1   Koramangala 5th Block    4.151507
# 2             Sankey Road    4.105882
# 3   Koramangala 3rd Block    4.101242
# 4         Cunningham Road    4.100300
# 5          St. Marks Road    4.099013
# 6   Koramangala 2nd Block    4.073333
# 7          Sadashiv Nagar    4.055263
# 8          Residency Road    4.051364
# 9           Church Street    4.045455
# 10  Koramangala 4th Block    4.044146
# 11          Seshadripuram    4.031884
# 12          Richmond Road    4.029060
# 13                 Ulsoor    4.021186
# 14            Koramangala    4.011765

# %%
# 2. Which locations are over-saturated with restaurants?

query = """SELECT
location, count(name) as Restaurant_count
From Restaurant_Data
Group by location
Order by Restaurant_count DESC
LIMIT 15
"""
df=pd.read_sql_query(query,conn)
df
# Out:
#                  location  Restaurant_count
# 0   Koramangala 5th Block              1782
# 1                     BTM              1454
# 2             Indiranagar              1346
# 3                     HSR              1161
# 4               Jayanagar              1037
# 5                JP Nagar              1016
# 6              Whitefield               824
# 7   Koramangala 7th Block               723
# 8   Koramangala 6th Block               718
# 9            Marathahalli               680
# 10  Koramangala 4th Block               644
# 11                MG Road               595
# 12           Brigade Road               567
# 13          Church Street               506
# 14      Bannerghatta Road               496

# %%
# 3. Does online ordering improve restaurant ratings?

query = """SELECT
online_order, AVG(rate) as Restaurant_Rating
FROM Restaurant_Data
Group by Online_order
Order by Restaurant_Rating DESC
"""
df = pd.read_sql_query(query,conn)
df
# Out:
#   online_order  Restaurant_Rating
# 0           No           3.929549
# 1          Yes           3.893425

# %%
# 4. Does table booking correlate with higher customer ratings?

query = """SELECT
book_table, AVG(rate) as Restaurant_Rating
FROM Restaurant_Data
Group by book_table
Order by Restaurant_Rating DESC
"""
df = pd.read_sql_query(query,conn)
df
# Out:
#   book_table  Restaurant_Rating
# 0        Yes           4.160189
# 1         No           3.813219

# %%
# 5. What price range delivers the best customer satisfaction?

query = """SELECT
approx_cost, AVG(rate) as Restaurant_Rating
FROM Restaurant_Data
Group by approx_cost
order by Restaurant_Rating DESC
LIMIT 15
"""
df = pd.read_sql_query(query,conn)
df
# Out:
#    approx_cost  Restaurant_Rating
# 0        2,700           4.500000
# 1        3,200           4.400000
# 2          120           4.400000
# 3        1,600           4.337447
# 4        3,500           4.328000
# 5        1,250           4.325000
# 6        6,000           4.300000
# 7        5,000           4.300000
# 8        4,500           4.300000
# 9        1,650           4.300000
# 10       3,400           4.300000
# 11       2,800           4.287097
# 12       1,700           4.281223
# 13       4,000           4.258333
# 14       1,400           4.236842

# %%
# 6. Which cuisines are most common in Bangalore?

query = """SELECT
cuisines, count(name) as Restaurant_count
FROM Restaurant_Data
Group by cuisines
order by Restaurant_count DESC
LIMIT 15
"""
df = pd.read_sql_query(query,conn)
df
# Out:
#                                cuisines  Restaurant_count
# 0                          North Indian              1144
# 1                 North Indian, Chinese               776
# 2                          South Indian               359
# 3                                  Cafe               273
# 4   South Indian, North Indian, Chinese               233
# 5                      Bakery, Desserts               215
# 6                   Desserts, Beverages               214
# 7                               Chinese               210
# 8                   Ice Cream, Desserts               208
# 9                              Desserts               206
# 10                              Biryani               169
# 11                       Chinese, Momos               162
# 12                          Finger Food               151
# 13                            Fast Food               150
# 14       North Indian, Chinese, Biryani               138

# %%
# 7. Which cuisines receive the highest average ratings?  check

query = """SELECT
cuisines, AVG(rate) as AVG_Restaurant_Rating
FROM Restaurant_Data
WHERE cuisines LIKE '%American%'
Group by cuisines
order by AVG_Restaurant_Rating DESC
LIMIT 20
"""
df = pd.read_sql_query(query,conn)
df
# Out:
#                                              cuisines  AVG_Restaurant_Rating
# 0             American, Tex-Mex, Burger, BBQ, Mexican               4.750000
# 1                            Italian, American, Pizza               4.700000
# 2   Chinese, American, Continental, Italian, North...               4.700000
# 3   American, Continental, North Indian, Mediterra...               4.650000
# 4                              Cafe, American, Burger               4.600000
# 5                   Cafe, American, Burger, Beverages               4.600000
# 6                       American, North Indian, Salad               4.600000
# 7        American, North Indian, Chinese, Finger Food               4.600000
# 8                       Cafe, American, Burger, Steak               4.595349
# 9        Continental, North Indian, Chinese, American               4.566667
# 10                     American, Tex-Mex, Burger, BBQ               4.550000
# 11  Continental, North Indian, Chinese, American, ...               4.500000
# 12  Continental, American, Italian, Modern Indian,...               4.500000
# 13                       American, Continental, Salad               4.500000
# 14         American, Continental, North Indian, Salad               4.500000
# 15                              American, Continental               4.500000
# 16  American, Cafe, Continental, French, Burger, M...               4.500000
# 17                                      American, BBQ               4.500000
# 18                  Modern Indian, European, American               4.450000
# 19                       American, Continental, Pizza               4.450000

# %%
# 8. Which cuisines perform well despite having fewer restaurants?

query = """SELECT
cuisines, count(name) as Restaurant_Count, AVG(rate) as AVG_Restaurant_Rating
FROM Restaurant_Data
WHERE cuisines LIKE '%Andhra%' and cuisines Like '%Biryani%'
Group by cuisines
order by Restaurant_Count
LIMIT 20
"""

df = pd.read_sql_query(query,conn)
df
# Out:
#                                              cuisines  Restaurant_Count  \
# 0                            Andhra, Chinese, Biryani                 1
# 1                         Andhra, Hyderabadi, Biryani                 1
# 2              Andhra, North Indian, Biryani, Seafood                 1
# 3                            Biryani, Mughlai, Andhra                 1
# 4                Hyderabadi, Andhra, Chinese, Biryani                 1
# 5     Andhra, North Indian, Chinese, Biryani, Seafood                 2
# 6                            Biryani, Chinese, Andhra                 2
# 7   Biryani, South Indian, North Indian, Chinese, ...                 2
# 8   Continental, Biryani, Pizza, North Indian, Chi...                 2
# 9                       South Indian, Andhra, Biryani                 2
# 10    Andhra, North Indian, Chinese, Seafood, Biryani                 3
# 11          Biryani, Hyderabadi, Andhra, North Indian                 3
# 12             Biryani, North Indian, Seafood, Andhra                 3
# 13                      Biryani, South Indian, Andhra                 3
# 14  Chinese, South Indian, Andhra, North Indian, B...                 3
# 15  Andhra, Biryani, Chinese, Hyderabadi, North In...                 4
# 16             Andhra, Biryani, Seafood, North Indian                 4
# 17  Andhra, Hyderabadi, Biryani, Chinese, North In...                 4
# 18           Andhra, North Indian, Biryani, Beverages                 4
# 19                      Andhra, South Indian, Biryani                 4
#
#     AVG_Restaurant_Rating
# 0                2.600000
# 1                3.700000
# 2                3.900000
# 3                4.600000
# 4                4.000000
# 5                3.800000
# 6                3.800000
# 7                3.700000
# 8                3.700000
# 9                3.700000
# 10               3.666667
# 11               3.800000
# 12               3.900000
# 13               3.800000
# 14               3.100000
# 15               4.000000
# 16               3.875000
# 17               4.100000
# 18               3.750000
# 19               3.325000

# %%
# 9. What is the relationship between restaurant cost and rating?

query = """SELECT
approx_cost, AVG(rate) as AVG_Restaurant_Rating
FROM Restaurant_Data
Group by approx_cost
order by AVG_Restaurant_Rating DESC
LIMIT 15
"""
df=pd.read_sql_query(query,conn)
df
# Out:
#    approx_cost  AVG_Restaurant_Rating
# 0        2,700               4.500000
# 1        3,200               4.400000
# 2          120               4.400000
# 3        1,600               4.337447
# 4        3,500               4.328000
# 5        1,250               4.325000
# 6        6,000               4.300000
# 7        5,000               4.300000
# 8        4,500               4.300000
# 9        1,650               4.300000
# 10       3,400               4.300000
# 11       2,800               4.287097
# 12       1,700               4.281223
# 13       4,000               4.258333
# 14       1,400               4.236842

# %%
# 10. Do restaurants offering both online ordering and table booking perform better?

query = """SELECT
online_order, book_table, AVG(rate) as AVG_Restaurant_Rating
FROM Restaurant_Data
Group by online_order, book_table
order by AVG_Restaurant_Rating DESC
"""
df = pd.read_sql_query(query,conn)
df
# Out:
#   online_order book_table  AVG_Restaurant_Rating
# 0           No        Yes               4.182135
# 1          Yes        Yes               4.145573
# 2          Yes         No               3.821445
# 3           No         No               3.789171

# %%
# 11. Which locations are ideal for premium restaurant onboarding?

query = """SELECT
location, Avg(rate) as AVG_Restaurant_Rating
FROM Restaurant_Data
Group by location
order by AVG_Restaurant_Rating DESC
LIMIT 15
"""
df = pd.read_sql_query(query,conn)
df
# Out:
#                  location  AVG_Restaurant_Rating
# 0            Lavelle Road               4.192534
# 1   Koramangala 5th Block               4.151507
# 2             Sankey Road               4.105882
# 3   Koramangala 3rd Block               4.101242
# 4         Cunningham Road               4.100300
# 5          St. Marks Road               4.099013
# 6   Koramangala 2nd Block               4.073333
# 7          Sadashiv Nagar               4.055263
# 8          Residency Road               4.051364
# 9           Church Street               4.045455
# 10  Koramangala 4th Block               4.044146
# 11          Seshadripuram               4.031884
# 12          Richmond Road               4.029060
# 13                 Ulsoor               4.021186
# 14            Koramangala               4.011765

# %%
# Adding and Reading json file

df1=pd.read_json("orders.json")
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_218/450909612.py in <cell line: 0>()
#       1 # Adding and Reading json file
#       2
# ----> 3 df1=pd.read_json("orders.json")
#       4 df1
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     789         convert_axes = True
#     790
# --> 791     json_reader = JsonReader(
#     792         path_or_buf,
#     793         orient=orient,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in __init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902             self.data = filepath_or_buffer
#     903         elif self.engine == "ujson":
# --> 904             data = self._get_data_from_filepath(filepath_or_buffer)
#     905             self.data = self._preprocess_data(data)
#     906
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/json/_json.py in _get_data_from_filepath(self, filepath_or_buffer)
#     958             and not file_exists(filepath_or_buffer)
#     959         ):
# --> 960             raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961         else:
#     962             warnings.warn(
#
# FileNotFoundError: File orders.json does not exist

# %%
df1.columns

# %%
data=df1.values.tolist()
data

# %%
# create a table

mycursor.execute("""
CREATE TABLE if not EXISTS Orders (
                 order_id INTEGER PRIMARY KEY AUTOINCREMENT,
                 restaurant_name VARCHAR(100) NOT NULL,
                 order_date VARCHAR(50),
                 order_value DECIMAL(3,1),
                 discount_used VARCHAR (50),
                 payment_method VARCHAR (50)
                 )""")
conn.commit()

# %%
# Insert data into table

query = """
INSERT INTO Orders
(restaurant_name, order_date, order_value,
 discount_used, payment_method)
VALUES (?, ?, ?, ?, ?)
"""

data = df1[['restaurant_name',
            'order_date',
            'order_value',
            'discount_used',
            'payment_method']].values.tolist()

mycursor.executemany(query, data)
conn.commit()

# %%
df1.drop_duplicates()

# %%
# 1. What is the total order_value on order_date 2026-01-22?

query = """SELECT
order_date, sum(order_value) as Total_Order_Value
FROM Orders
WHERE order_date = '2026-01-22'
"""
df1 = pd.read_sql_query(query,conn)
df1

# %%
# 2. What is the relationship between order_value and discount_used?

query = """SELECT
discount_used, AVG(order_value) as AVG_Order_Value
FROM Orders
Group by discount_used
order by AVG_order_value DESC
"""

df1 = pd.read_sql_query(query,conn)
df1

# %%
# 3. Most used payment method?

query = """SELECT
payment_method, count(payment_method) as Payment_Method_Count
FROM Orders
Group by payment_method
order by Payment_Method_Count
"""

df1 = pd.read_sql_query(query,conn)
df1

# %%
# 4. will discount increase order value?

query = """SELECT
discount_used, AVG(order_value) as AVG_Order_Value
FROM Orders
Group by discount_used
order by AVG_order_value DESC
"""

df1 = pd.read_sql_query(query,conn)
df1

# %%
# 5. Which restaurant generates highest revenue?

query = """SELECT
restaurant_name, sum(order_value) as Total_Revenue
FROM Orders
Group by restaurant_name
order by Total_Revenue DESC
LIMIT 16
"""

df1 = pd.read_sql_query(query,conn)
df1

# %%
# 6. Which date had highest revenue?

query = """SELECT
order_date, sum(order_value) as Revenue
From orders
Group by order_date
order by Revenue DESC
LIMIT 10
"""

df1 = pd.read_sql_query(query,conn)
df1

# %%
# 7. on which order_date discounts are used the most?

query = """SELECT
order_date, count(discount_used) as Total_Discounts
FROM orders
GROUP BY order_date
ORDER BY Total_Discounts DESC
LIMIT 15
"""

df1 = pd.read_sql_query(query,conn)
df1

# %%
# 8. what is the order date where highest no:of orders taken place in restaurant?

query = """SELECT
order_date, restaurant_name, count(restaurant_name) as Highest_orders
FROM orders
group by order_date, restaurant_name
order by Highest_orders DESC
limit 20
"""

df1 = pd.read_sql_query(query,conn)
df1
